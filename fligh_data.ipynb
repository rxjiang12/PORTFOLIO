# %% [markdown]
# <a href="https://colab.research.google.com/github/Iamkoss/cis9650_flight_data/blob/main/fligh_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis of Flight Data from the Buffalo, NY Airport

# %% [markdown]
# ### Author: Anna Bold, Kossi Gamli, Ran Xin Jiang, Christina Pratas
# ### Date : December 8th, 2025

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 1. Introduction
# 2. Problem Statement / Research Question
# 3. Data Description
# 4. Setup and Environment
# 5. Data Loading
# 6. Data Preparation
# 7. Model Planning
# 8. Model Building / Analysis
# 9. Discussion & Interpretation
# 10. Conclusion
# 11. References
# 12. Appendix

# %% [markdown]
# ## Introduction
# This projects examines flight records from Buffalo Niagara International Airport (BUF) for most of January 2025. The following 30 JSON files contain detailed information regarding flight schedules, scheduled arrival and departure times, airports, and aircraft information. The dataset shows how flights operated throughout the month, including patterns in delays, cancellations, airline performance, and schedule consistency. By organizing this raw data into a structured format, it highlights these trends and provides a clearer picture of BUF's activity during this period.

# %% [markdown]
# ## Problem Statement / Research Question

# %% [markdown]
# The research question looks to find out what overlying issues the Buffalo Niagara International Airport may be having with the daily arriving and departing flights in January 2025. There are several different factors to look at, including potential problematic airlines, large discrepancies between scheduled departure/arrival times and actual departure/arrival times, and outlying flight cancellations.
#
# The hypothesis will look to see if certain airlines, time of day, or gate placement within the airport have significance in potential delays or cancellations. The hypothesis will also look to see if any outside factors, such as inclement weather, may have resulted in delays or cancellations.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data was presented in a series of 30 JSON files.
#
# Combined, there were a total of 5509 rows of data and 46 columns of categories.

# %% [markdown]
# ## Setup and Environment

# %%
# !pip install google-cloud-storage
# Out:
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (3.6.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.43.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.32.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.11.12)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.1)

# %%
# !git clone https://github.com/Iamkoss/cis9650_flight_data.git
# Out:
# fatal: destination path 'cis9650_flight_data' already exists and is not an empty directory.

# %%
from google.cloud import storage
from io import BytesIO
from io import BytesIO
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import json
import os
import glob

# %% [markdown]
# ## Data Loading

# %%
# Find all BUF json files
files = sorted(glob.glob("/content/cis9650_flight_data/BUF*.json"))

#checking to see if all the files were successful found:
print("Files found:", files)
print("Number of files found:", len(files))

# Store each file's data as a *separate* DataFrame
flight_dfs = {}  # dictionary: file_name → DataFrame

for file in files:
    print("Loading:", (file))

    with open(file, "r") as f:
        data = json.load(f)

    df = pd.json_normalize(data)

    # Save each DataFrame with name like "BUF_1"
    key = os.path.basename(file).replace(".json", "")
    flight_dfs[key] = df

#checking to see that all keys were loaded correctly
print("\nLoaded files (keys):", list(flight_dfs.keys()))
print("Number of DataFrames loaded:", len(flight_dfs))

###combine all dataframes together
if len(flight_dfs) > 0:
  df_all = pd.concat(flight_dfs.values(), ignore_index=True)
  print("Combined: ", df_all.shape)
  df_all.head()
else:
  print("No DataFrames to combine.")
# Out:
# Files found: ['/content/cis9650_flight_data/BUF_1.json', '/content/cis9650_flight_data/BUF_10.json', '/content/cis9650_flight_data/BUF_11.json', '/content/cis9650_flight_data/BUF_12.json', '/content/cis9650_flight_data/BUF_13.json', '/content/cis9650_flight_data/BUF_14.json', '/content/cis9650_flight_data/BUF_15.json', '/content/cis9650_flight_data/BUF_16.json', '/content/cis9650_flight_data/BUF_17.json', '/content/cis9650_flight_data/BUF_18.json', '/content/cis9650_flight_data/BUF_19.json', '/content/cis9650_flight_data/BUF_2.json', '/content/cis9650_flight_data/BUF_20.json', '/content/cis9650_flight_data/BUF_21.json', '/content/cis9650_flight_data/BUF_22.json', '/content/cis9650_flight_data/BUF_23.json', '/content/cis9650_flight_data/BUF_24.json', '/content/cis9650_flight_data/BUF_25.json', '/content/cis9650_flight_data/BUF_26.json', '/content/cis9650_flight_data/BUF_27.json', '/content/cis9650_flight_data/BUF_28.json', '/content/cis9650_flight_data/BUF_29.json', '/content/cis9650_flight_data/BUF_3.json', '/content/cis9650_flight_data/BUF_30.json', '/content/cis9650_flight_data/BUF_4.json', '/content/cis9650_flight_data/BUF_5.json', '/content/cis9650_flight_data/BUF_6.json', '/content/cis9650_flight_data/BUF_7.json', '/content/cis9650_flight_data/BUF_8.json', '/content/cis9650_flight_data/BUF_9.json']
# Number of files found: 30
# Loading: /content/cis9650_flight_data/BUF_1.json
# Loading: /content/cis9650_flight_data/BUF_10.json
# Loading: /content/cis9650_flight_data/BUF_11.json
# Loading: /content/cis9650_flight_data/BUF_12.json
# Loading: /content/cis9650_flight_data/BUF_13.json
# Loading: /content/cis9650_flight_data/BUF_14.json
# Loading: /content/cis9650_flight_data/BUF_15.json
# Loading: /content/cis9650_flight_data/BUF_16.json
# Loading: /content/cis9650_flight_data/BUF_17.json
# Loading: /content/cis9650_flight_data/BUF_18.json
# Loading: /content/cis9650_flight_data/BUF_19.json
# Loading: /content/cis9650_flight_data/BUF_2.json
# Loading: /content/cis9650_flight_data/BUF_20.json
# Loading: /content/cis9650_flight_data/BUF_21.json
# Loading: /content/cis9650_flight_data/BUF_22.json
# Loading: /content/cis9650_flight_data/BUF_23.json
# Loading: /content/cis9650_flight_data/BUF_24.json
# Loading: /content/cis9650_flight_data/BUF_25.json
# Loading: /content/cis9650_flight_data/BUF_26.json
# Loading: /content/cis9650_flight_data/BUF_27.json
# Loading: /content/cis9650_flight_data/BUF_28.json
# Loading: /content/cis9650_flight_data/BUF_29.json
# Loading: /content/cis9650_flight_data/BUF_3.json
# Loading: /content/cis9650_flight_data/BUF_30.json
# Loading: /content/cis9650_flight_data/BUF_4.json
# Loading: /content/cis9650_flight_data/BUF_5.json
# Loading: /content/cis9650_flight_data/BUF_6.json
# Loading: /content/cis9650_flight_data/BUF_7.json
# Loading: /content/cis9650_flight_data/BUF_8.json
# Loading: /content/cis9650_flight_data/BUF_9.json
#
# Loaded files (keys): ['BUF_1', 'BUF_10', 'BUF_11', 'BUF_12', 'BUF_13', 'BUF_14', 'BUF_15', 'BUF_16', 'BUF_17', 'BUF_18', 'BUF_19', 'BUF_2', 'BUF_20', 'BUF_21', 'BUF_22', 'BUF_23', 'BUF_24', 'BUF_25', 'BUF_26', 'BUF_27', 'BUF_28', 'BUF_29', 'BUF_3', 'BUF_30', 'BUF_4', 'BUF_5', 'BUF_6', 'BUF_7', 'BUF_8', 'BUF_9']
# Number of DataFrames loaded: 30
# Combined:  (5509, 46)

# %%
print(files)
print(len(files))
# Out:
# ['/content/cis9650_flight_data/BUF_1.json', '/content/cis9650_flight_data/BUF_10.json', '/content/cis9650_flight_data/BUF_11.json', '/content/cis9650_flight_data/BUF_12.json', '/content/cis9650_flight_data/BUF_13.json', '/content/cis9650_flight_data/BUF_14.json', '/content/cis9650_flight_data/BUF_15.json', '/content/cis9650_flight_data/BUF_16.json', '/content/cis9650_flight_data/BUF_17.json', '/content/cis9650_flight_data/BUF_18.json', '/content/cis9650_flight_data/BUF_19.json', '/content/cis9650_flight_data/BUF_2.json', '/content/cis9650_flight_data/BUF_20.json', '/content/cis9650_flight_data/BUF_21.json', '/content/cis9650_flight_data/BUF_22.json', '/content/cis9650_flight_data/BUF_23.json', '/content/cis9650_flight_data/BUF_24.json', '/content/cis9650_flight_data/BUF_25.json', '/content/cis9650_flight_data/BUF_26.json', '/content/cis9650_flight_data/BUF_27.json', '/content/cis9650_flight_data/BUF_28.json', '/content/cis9650_flight_data/BUF_29.json', '/content/cis9650_flight_data/BUF_3.json', '/content/cis9650_flight_data/BUF_30.json', '/content/cis9650_flight_data/BUF_4.json', '/content/cis9650_flight_data/BUF_5.json', '/content/cis9650_flight_data/BUF_6.json', '/content/cis9650_flight_data/BUF_7.json', '/content/cis9650_flight_data/BUF_8.json', '/content/cis9650_flight_data/BUF_9.json']
# 145  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 146  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 147  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 148  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 149  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 150  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 151  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 152  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 153  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 154  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 155  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 156  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 157  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 158  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 159  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 160  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 161  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 162  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 163  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 164  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 165  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 166  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 167  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 168  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 169  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 170  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 171  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 172  2025-01-28        landed       NaN  None  Buffalo Niagara International
#
#     departure.timezone departure.iata departure.icao departure.terminal  \
# 0     America/New_York            BUF           KBUF               None
# 1     America/New_York            BUF           KBUF               None
# 2     America/New_York            BUF           KBUF               None
# 3     America/New_York            BUF           KBUF               None
# 4     America/New_York            BUF           KBUF               None
# 5     America/New_York            BUF           KBUF               None
# 6     America/New_York            BUF           KBUF               None
# 7     America/New_York            BUF           KBUF               None
# 8     America/New_York            BUF           KBUF               None
# 9     America/New_York            BUF           KBUF               None
# 10    America/New_York            BUF           KBUF               None
# 11    America/New_York            BUF           KBUF               None
# 12    America/New_York            BUF           KBUF               None
# 13    America/New_York            BUF           KBUF               None
# 14    America/New_York            BUF           KBUF               None
# 15    America/New_York            BUF           KBUF               None
# 16    America/New_York            BUF           KBUF               None
# 17    America/New_York            BUF           KBUF               None
# 18    America/New_York            BUF           KBUF               None
# 19    America/New_York            BUF           KBUF               None
# 20    America/New_York            BUF           KBUF               None
# 21    America/New_York            BUF           KBUF               None
# 22    America/New_York            BUF           KBUF               None
# 23    America/New_York            BUF           KBUF               None
# 24    America/New_York            BUF           KBUF               None
# 25    America/New_York            BUF           KBUF               None
# 26    America/New_York            BUF           KBUF               None
# 27    America/New_York            BUF           KBUF               None
# 28    America/New_York            BUF           KBUF               None
# 29    America/New_York            BUF           KBUF               None
# 30    America/New_York            BUF           KBUF               None
# 31    America/New_York            BUF           KBUF               None
# 32    America/New_York            BUF           KBUF               None
# 33    America/New_York            BUF           KBUF               None
# 34    America/New_York            BUF           KBUF               None
# 35    America/New_York            BUF           KBUF               None
# 36    America/New_York            BUF           KBUF               None
# 37    America/New_York            BUF           KBUF               None
# 38    America/New_York            BUF           KBUF               None
# 39    America/New_York            BUF           KBUF               None
# 40    America/New_York            BUF           KBUF               None
# 41    America/New_York            BUF           KBUF               None
# 42    America/New_York            BUF           KBUF               None
# 43    America/New_York            BUF           KBUF               None
# 44    America/New_York            BUF           KBUF               None
# 45    America/New_York            BUF           KBUF               None
# 46    America/New_York            BUF           KBUF               None
# 47    America/New_York            BUF           KBUF               None
# 48    America/New_York            BUF           KBUF               None
# 49    America/New_York            BUF           KBUF               None
# 50    America/New_York            BUF           KBUF               None
# 51    America/New_York            BUF           KBUF               None
# 52    America/New_York            BUF           KBUF               None
# 53    America/New_York            BUF           KBUF               None
# 54    America/New_York            BUF           KBUF               None
# 55    America/New_York            BUF           KBUF               None
# 56    America/New_York            BUF           KBUF               None
# 57    America/New_York            BUF           KBUF               None
# 58    America/New_York            BUF           KBUF               None
# 59    America/New_York            BUF           KBUF               None
# 60    America/New_York            BUF           KBUF               None
# 61    America/New_York            BUF           KBUF               None
# 62    America/New_York            BUF           KBUF               None
# 63    America/New_York            BUF           KBUF               None
# 64    America/New_York            BUF           KBUF               None
# 65    America/New_York            BUF           KBUF               None
# 66    America/New_York            BUF           KBUF               None
# 67    America/New_York            BUF           KBUF               None
# 68    America/New_York            BUF           KBUF               None
# 69    America/New_York            BUF           KBUF               None
# 70    America/New_York            BUF           KBUF               None
# 71    America/New_York            BUF           KBUF               None
# 72    America/New_York            BUF           KBUF               None
# 73    America/New_York            BUF           KBUF               None
# 74    America/New_York            BUF           KBUF               None
# 75    America/New_York            BUF           KBUF               None
# 76    America/New_York            BUF           KBUF               None
# 77    America/New_York            BUF           KBUF               None
# 78    America/New_York            BUF           KBUF               None
# 79    America/New_York            BUF           KBUF               None
# 80    America/New_York            BUF           KBUF               None
# 81    America/New_York            BUF           KBUF               None
# 82    America/New_York            BUF           KBUF               None
# 83    America/New_York            BUF           KBUF               None
# 84    America/New_York            BUF           KBUF               None
# 85    America/New_York            BUF           KBUF               None
# 86    America/New_York            BUF           KBUF               None
# 87    America/New_York            BUF           KBUF               None
# 88    America/New_York            BUF           KBUF               None
# 89    America/New_York            BUF           KBUF               None
# 90    America/New_York            BUF           KBUF               None
# 91    America/New_York            BUF           KBUF               None
# 92    America/New_York            BUF           KBUF               None
# 93    America/New_York            BUF           KBUF               None
# 94    America/New_York            BUF           KBUF               None
# 95    America/New_York            BUF           KBUF               None
# 96    America/New_York            BUF           KBUF               None
# 97    America/New_York            BUF           KBUF               None
# 98    America/New_York            BUF           KBUF               None
# 99    America/New_York            BUF           KBUF               None
# 100   America/New_York            BUF           KBUF               None
# 101   America/New_York            BUF           KBUF               None
# 102   America/New_York            BUF           KBUF               None
# 103   America/New_York            BUF           KBUF               None
# 104   America/New_York            BUF           KBUF               None
# 105   America/New_York            BUF           KBUF               None
# 106   America/New_York            BUF           KBUF               None
# 107   America/New_York            BUF           KBUF               None
# 108   America/New_York            BUF           KBUF               None
# 109   America/New_York            BUF           KBUF               None
# 110   America/New_York            BUF           KBUF               None
# 111   America/New_York            BUF           KBUF               None
# 112   America/New_York            BUF           KBUF               None
# 113   America/New_York            BUF           KBUF               None
# 114   America/New_York            BUF           KBUF               None
# 115   America/New_York            BUF           KBUF               None
# 116   America/New_York            BUF           KBUF               None
# 117   America/New_York            BUF           KBUF               None
# 118   America/New_York            BUF           KBUF               None
# 119   America/New_York            BUF           KBUF               None
# 120   America/New_York            BUF           KBUF               None
# 121   America/New_York            BUF           KBUF               None
# 122   America/New_York            BUF           KBUF               None
# 123   America/New_York            BUF           KBUF               None
# 124   America/New_York            BUF           KBUF               None
# 125   America/New_York            BUF           KBUF               None
# 126   America/New_York            BUF           KBUF               None
# 127   America/New_York            BUF           KBUF               None
# 128   America/New_York            BUF           KBUF               None
# 129   America/New_York            BUF           KBUF               None
# 130   America/New_York            BUF           KBUF               None
# 131   America/New_York            BUF           KBUF               None
# 132   America/New_York            BUF           KBUF               None
# 133   America/New_York            BUF           KBUF               None
# 134   America/New_York            BUF           KBUF               None
# 135   America/New_York            BUF           KBUF               None
# 136   America/New_York            BUF           KBUF               None
# 137   America/New_York            BUF           KBUF               None
# 138   America/New_York            BUF           KBUF               None
# 139   America/New_York            BUF           KBUF               None
# 140   America/New_York            BUF           KBUF               None
# 141   America/New_York            BUF           KBUF               None
# 142   America/New_York            BUF           KBUF               None
# 143   America/New_York            BUF           KBUF               None
# 144   America/New_York            BUF           KBUF               None
# 145   America/New_York            BUF           KBUF               None
# 146   America/New_York            BUF           KBUF               None
# 147   America/New_York            BUF           KBUF               None
# 148   America/New_York            BUF           KBUF               None
# 149   America/New_York            BUF           KBUF               None
# 150   America/New_York            BUF           KBUF               None
# 151   America/New_York            BUF           KBUF               None
# 152   America/New_York            BUF           KBUF               None
# 153   America/New_York            BUF           KBUF               None
# 154   America/New_York            BUF           KBUF               None
# 155   America/New_York            BUF           KBUF               None
# 156   America/New_York            BUF           KBUF               None
# 157   America/New_York            BUF           KBUF               None
# 158   America/New_York            BUF           KBUF               None
# 159   America/New_York            BUF           KBUF               None
# 160   America/New_York            BUF           KBUF               None
# 161   America/New_York            BUF           KBUF               None
# 162   America/New_York            BUF           KBUF               None
# 163   America/New_York            BUF           KBUF               None
# 164   America/New_York            BUF           KBUF               None
# 165   America/New_York            BUF           KBUF               None
# 166   America/New_York            BUF           KBUF               None
# 167   America/New_York            BUF           KBUF               None
# 168   America/New_York            BUF           KBUF               None
# 169   America/New_York            BUF           KBUF               None
# 170   America/New_York            BUF           KBUF               None
# 171   America/New_York            BUF           KBUF               None
# 172   America/New_York            BUF           KBUF               None
#
#     departure.gate  departure.delay        departure.scheduled  \
# 1            CRJ7          CRJ7          A677BE
# 2            A321          A321          A07522
# 3            E145          E145          A895B0
# 4             NaN           NaN             NaN
# 5             NaN           NaN             NaN
# 6             NaN           NaN             NaN
# 7             NaN           NaN             NaN
# 8             NaN           NaN             NaN
# 9             NaN           NaN             NaN
# 10            NaN           NaN             NaN
# 11            NaN           NaN             NaN
# 12           A320          A320          A707A3
# 13            NaN           NaN             NaN
# 14           BCS3          BCS3          A36B50
# 15            NaN           NaN             NaN
# 16            NaN           NaN             NaN
# 17            NaN           NaN             NaN
# 18            NaN           NaN             NaN
# 19            NaN           NaN             NaN
# 20            NaN           NaN             NaN
# 21           B739          B739          AC382E
# 22           CRJ9          CRJ9          A5E02D
# 23           E170          E170          A880C8
# 24           B38M          B38M          AC0F93
# 25            NaN           NaN             NaN
# 26            NaN           NaN             NaN
# 27           A320          A320          A414FB
# 28           E75L          E75L          A50549
# 29           B737          B737          A5540C
# 30            NaN           NaN             NaN
# 31            NaN           NaN             NaN
# 32            NaN           NaN             NaN
# 33            NaN           NaN             NaN
# 34            NaN           NaN             NaN
# 35            NaN           NaN             NaN
# 36           CRJ9          CRJ9          A30961
# 37            NaN           NaN             NaN
# 38            NaN           NaN             NaN
# 39            NaN           NaN             NaN
# 40            NaN           NaN             NaN
# 41           A319          A319          AC0AAC
# 42           B752          B752          A553DB
# 43            NaN           NaN             NaN
# 44            NaN           NaN             NaN
# 45            NaN           NaN             NaN
# 46           E170          E170          AAB396
# 47           A21N          A21N          A8BC34
# 48           B38M          B38M          AC16DA
# 49           A306          A306          A07D01
# 50           B737          B737          ACD2BE
# 51            NaN           NaN             NaN
# 52            NaN           NaN             NaN
# 53            NaN           NaN             NaN
# 54            NaN           NaN             NaN
# 55            NaN           NaN             NaN
# 56            NaN           NaN             NaN
# 57            NaN           NaN             NaN
# 58           BCS3          BCS3          A358BD
# 59            NaN           NaN             NaN
# 60           B738          B738          AB8CA5
# 61            NaN           NaN             NaN
# 62            NaN           NaN             NaN
# 63            NaN           NaN             NaN
# 64           E45X          E45X          A03397
# 65            NaN           NaN             NaN
# 66           A321          A321          AD4BCB
# 67           CRJ9          CRJ9          A39ADA
# 68            NaN           NaN             NaN
# 69            NaN           NaN             NaN
# 70           B738          B738          ABD5BB
# 71           A319          A319          AAFBF3
# 72            NaN           NaN             NaN
# 73            NaN           NaN             NaN
# 74            NaN           NaN             NaN
# 75            NaN           NaN             NaN
# 76            NaN           NaN             NaN
# 77            NaN           NaN             NaN
# 78            NaN           NaN             NaN
# 79            NaN           NaN             NaN
# 80           CRJ9          CRJ9          A33AA7
# 81            NaN           NaN             NaN
# 82            NaN           NaN             NaN
# 83            NaN           NaN             NaN
# 84           CRJ7          CRJ7          A6496B
# 85           E75L          E75L          A51F4A
# 86            NaN           NaN             NaN
# 87            NaN           NaN             NaN
# 88            NaN           NaN             NaN
# 89           CRJ9          CRJ9          A11A81
# 90            NaN           NaN             NaN
# 91           CRJ7          CRJ7          A993AD
# 92            NaN           NaN             NaN
# 93            NaN           NaN             NaN
# 94            NaN           NaN             NaN
# 95           E145          E145          A90AAA
# 96            NaN           NaN             NaN
# 97            NaN           NaN             NaN
# 98           B38M          B38M          AC2F18
# 99           B737          B737          A2685B
# 100          B738          B738          ABD971
# 101           NaN           NaN             NaN
# 102           NaN           NaN             NaN
# 103           NaN           NaN             NaN
# 104           NaN           NaN             NaN
# 105           NaN           NaN             NaN
# 106           NaN           NaN             NaN
# 107          B739          B739          AD4F0B
# 108          CRJ9          CRJ9          ACC040
# 109           NaN           NaN             NaN
# 110           NaN           NaN             NaN
# 111           NaN           NaN             NaN
# 112          E75L          E75L          AAF002
# 113           NaN           NaN             NaN
# 114          CRJ7          CRJ7          A69061
# 115           NaN           NaN             NaN
# 116           NaN           NaN             NaN
# 117           NaN           NaN             NaN
# 118           NaN           NaN             NaN
# 119          E170          E170          A9F64B
# 120          B737          B737          A280FE
# 121           NaN           NaN             NaN
# 122           NaN           NaN             NaN
# 123           NaN           NaN             NaN
# 124           NaN           NaN             NaN
# 125          CRJ9          CRJ9          AC92B1
# 126           NaN           NaN             NaN
# 127           NaN           NaN             NaN
# 128           NaN           NaN             NaN
# 129           NaN           NaN             NaN
# 130           NaN           NaN             NaN
# 131           NaN           NaN             NaN
# 132           NaN           NaN             NaN
# 133          BCS3          BCS3          A36B73
# 134          CRJ9          CRJ9          A148B9
# 135           NaN           NaN             NaN
# 136           NaN           NaN             NaN
# 137           NaN           NaN             NaN
# 138           NaN           NaN             NaN
# 139           NaN           NaN             NaN
# 140           NaN           NaN             NaN
# 141          B737          B737          AA9AB6
# 142          E75L          E75L          A51F4A
# 143          B38M          B38M          AC47B7
# 144          CRJ7          CRJ7          A64C88
# 145           NaN           NaN             NaN
# 146           NaN           NaN             NaN
# 147          E170          E170          A89D22
# 148           NaN           NaN             NaN
# 149          E75L          E75L          A2ED5A
# 150          A320          A320          A02443
# 151          CRJ7          CRJ7          A690FB
# 152           NaN           NaN             NaN
# 153          E45X          E45X          A00B91
# 154           NaN           NaN             NaN
# 155           NaN           NaN             NaN
# 156           NaN           NaN             NaN
# 157          BCS3          BCS3          A33CA9
# 158           NaN           NaN             NaN
# 159           NaN           NaN             NaN
# 160           NaN           NaN             NaN
# 161           NaN           NaN             NaN
# 162          CRJ9          CRJ9          A0BA4E
# 163           NaN           NaN             NaN
# 164          B752          B752          AD002B
# 165          A306          A306          A0DADB
# 166          B752          B752          A83178
# 167           NaN           NaN             NaN
# 168           NaN           NaN             NaN
# 169          B752          B752          A5CE0F
# 170           NaN           NaN             NaN
# 171           NaN           NaN             NaN
# 172           NaN           NaN             NaN

# %%
#clean up the entire data set (ie. fix the naming of some columns)

#making a copy of the master set (in case of mess up)
df = df_all.copy()
#replacting the column names from . to a _ for easier reading
df.columns = df.columns.str.lower().str.replace('.', '_')

# Removing all the fully empty row
#empty_cols = df.columns[df.isna().all()].tolist()
#df = df.drop(columns=empty_cols)
#print("Dropped completely empty columns:", empty_cols)

#remove any duplicates from main set
df = df.drop_duplicates()
# 4  2025-01-05T06:15:00+00:00  Southwest Airlines           WN          SWA
# 5  2025-01-05T07:46:00+00:00   American Airlines           AA          AAL
# 6  2025-01-05T07:30:00+00:00   American Airlines           AA          AAL
# 7  2025-01-05T07:35:00+00:00     Delta Air Lines           DL          DAL
# 8  2025-01-05T07:45:00+00:00     United Airlines           UA          UAL
# 9  2025-01-05T08:29:00+00:00  Southwest Airlines           WN          SWA
#
#   flight_number flight_iata flight_icao  flight_codeshared  \
# 0          3010      WN3010     SWA3010                NaN
# 1          None        None        None                NaN
# 2          6125      AS6125     JAG6125                NaN
# 3          5163      AA5163     AAL5163                NaN
# 4          1357      WN1357     SWA1357                NaN
# 5          1204      AA1204     AAL1204                NaN
# 6          4737      AA4737     AAL4737                NaN
# 7          5825      DL5825     DAL5825                NaN
# 8          1598      UA1598     UAL1598                NaN
# 9          1439      WN1439     SWA1439                NaN
#
#   aircraft_registration aircraft_iata aircraft_icao aircraft_icao24  aircraft  \
# 0                N8835Q          B38M          B38M          AC2C10       NaN
# 1                   NaN           NaN           NaN             NaN       NaN
# 2                   NaN           NaN           NaN             NaN       NaN
# 3                N534AE          CRJ7          CRJ7          A6BF4E       NaN
# 4                N8919K          B38M          B38M          AC4CA8       NaN
# 5                N179UW          A321          A321          A13C73       NaN
# 6                N430YX          E75L          E75L          A5255A       NaN
# 7                N815MD          E170          E170          AB1D06       NaN
# 8                N68843          B739          B739          A923EF       NaN
# 9                N950WN          B737          B737          AD36A8       NaN
#
#   flight_codeshared_airline_name flight_codeshared_airline_iata  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2              american airlines                             aa
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# 5                            NaN                            NaN
# 6                            NaN                            NaN
# 7                            NaN                            NaN
# 8                            NaN                            NaN
# 9                            NaN                            NaN
#
#   flight_codeshared_airline_icao flight_codeshared_flight_number  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            aal                            5163
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# 5                            NaN                             NaN
# 6                            NaN                             NaN
# 7                            NaN                             NaN
# 8                            NaN                             NaN
# 9                            NaN                             NaN
#
#   flight_codeshared_flight_iata flight_codeshared_flight_icao
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                        aa5163                       aal5163
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# 5                           NaN                           NaN
# 6                           NaN                           NaN
# 7                           NaN                           NaN
# 8                           NaN                           NaN
# 9                           NaN                           NaN

# %%
display(df.head())
display(df.info())
df.isna().sum()
# Out:
#   flight_date flight_status  live              departure_airport  \
# 0  2025-01-05        landed  None  Buffalo Niagara International
# 1  2025-01-05        landed  None  Buffalo Niagara International
# 2  2025-01-05        landed  None  Buffalo Niagara International
# 3  2025-01-05        landed  None  Buffalo Niagara International
# 4  2025-01-05        landed  None  Buffalo Niagara International
#
#   departure_timezone departure_iata departure_icao departure_terminal  \
# 0   America/New_York            BUF           KBUF               None
# 1   America/New_York            BUF           KBUF               None
# 1          None        None        None                NaN
# 2          6125      AS6125     JAG6125                NaN
# 3          5163      AA5163     AAL5163                NaN
# 4          1357      WN1357     SWA1357                NaN
#
#   aircraft_registration aircraft_iata aircraft_icao aircraft_icao24  aircraft  \
# 0                N8835Q          B38M          B38M          AC2C10       NaN
# 1                   NaN           NaN           NaN             NaN       NaN
# 2                   NaN           NaN           NaN             NaN       NaN
# 3                N534AE          CRJ7          CRJ7          A6BF4E       NaN
# 4                N8919K          B38M          B38M          AC4CA8       NaN
#
#   flight_codeshared_airline_name flight_codeshared_airline_iata  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2              american airlines                             aa
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#   flight_codeshared_airline_icao flight_codeshared_flight_number  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            aal                            5163
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   flight_codeshared_flight_iata flight_codeshared_flight_icao
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                        aa5163                       aal5163
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5509 entries, 0 to 5508
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   flight_date                      5509 non-null   object
#  1   flight_status                    5509 non-null   object
#  2   live                             0 non-null      object
#  3   departure_airport                5509 non-null   object
#  4   departure_timezone               5509 non-null   object
#  5   departure_iata                   5509 non-null   object
#  6   departure_icao                   5509 non-null   object
#  7   departure_terminal               0 non-null      object
#  8   departure_gate                   4883 non-null   object
#  9   departure_delay                  4812 non-null   float64
#  10  departure_scheduled              5509 non-null   object
#  11  departure_estimated              5509 non-null   object
#  12  departure_actual                 4145 non-null   object
#  13  departure_estimated_runway       4145 non-null   object
#  14  departure_actual_runway          4145 non-null   object
#  15  arrival_airport                  5494 non-null   object
#  16  arrival_timezone                 5488 non-null   object
#  17  arrival_iata                     5509 non-null   object
#  18  arrival_icao                     5508 non-null   object
#  19  arrival_terminal                 4890 non-null   object
#  20  arrival_gate                     4890 non-null   object
#  21  arrival_baggage                  4683 non-null   object
#  22  arrival_scheduled                5509 non-null   object
#  23  arrival_delay                    1061 non-null   float64
#  24  arrival_estimated                2799 non-null   object
#  25  arrival_actual                   2698 non-null   object
#  26  arrival_estimated_runway         2698 non-null   object
#  27  arrival_actual_runway            2698 non-null   object
#  28  airline_name                     5509 non-null   object
#  29  airline_iata                     5236 non-null   object
#  30  airline_icao                     5373 non-null   object
#  31  flight_number                    5353 non-null   object
#  32  flight_iata                      5236 non-null   object
#  33  flight_icao                      5373 non-null   object
#  34  flight_codeshared                0 non-null      float64
#  35  aircraft_registration            1921 non-null   object
#  36  aircraft_iata                    1921 non-null   object
#  37  aircraft_icao                    1921 non-null   object
#  38  aircraft_icao24                  1921 non-null   object
#  39  aircraft                         0 non-null      float64
#  40  flight_codeshared_airline_name   3129 non-null   object
#  41  flight_codeshared_airline_iata   3129 non-null   object
#  42  flight_codeshared_airline_icao   3129 non-null   object
#  43  flight_codeshared_flight_number  3129 non-null   object
#  44  flight_codeshared_flight_iata    3129 non-null   object
#  45  flight_codeshared_flight_icao    3129 non-null   object
# dtypes: float64(4), object(42)
# memory usage: 1.9+ MB
# None
# flight_date                           0
# flight_status                         0
# live                               5509
# departure_airport                     0
# departure_timezone                    0
# departure_iata                        0
# departure_icao                        0
# departure_terminal                 5509
# departure_gate                      626
# departure_delay                     697
# departure_scheduled                   0
# departure_estimated                   0
# departure_actual                   1364
# departure_estimated_runway         1364
# departure_actual_runway            1364
# arrival_airport                      15
# arrival_timezone                     21
# arrival_iata                          0
# arrival_icao                          1
# arrival_terminal                    619
# arrival_gate                        619
# arrival_baggage                     826
# arrival_scheduled                     0
# arrival_delay                      4448
# arrival_estimated                  2710
# arrival_actual                     2811
# arrival_estimated_runway           2811
# arrival_actual_runway              2811
# airline_name                          0
# airline_iata                        273
# airline_icao                        136
# flight_number                       156
# flight_iata                         273
# flight_icao                         136
# flight_codeshared                  5509
# aircraft_registration              3588
# aircraft_iata                      3588
# aircraft_icao                      3588
# aircraft_icao24                    3588
# aircraft                           5509
# flight_codeshared_airline_name     2380
# flight_codeshared_airline_iata     2380
# flight_codeshared_airline_icao     2380
# flight_codeshared_flight_number    2380
# flight_codeshared_flight_iata      2380
# flight_codeshared_flight_icao      2380
# dtype: int64

# %%
#convert the date and time columns to datetime

# Convert main flight date
df['flight_date'] = pd.to_datetime(df['flight_date'], errors='coerce')

# List of time columns to convert
time_columns = [
    'departure_scheduled', 'departure_estimated', 'departure_actual',
    'arrival_scheduled', 'arrival_estimated', 'arrival_actual'
]

# Convert each to datetime
for col in time_columns:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors='coerce')

df[['flight_date', 'departure_scheduled', 'departure_actual', 'arrival_scheduled', 'arrival_actual']].head()
# Out:
#   flight_date       departure_scheduled          departure_actual  \
# 0  2025-01-05 2025-01-05 05:00:00+00:00 2025-01-05 05:20:00+00:00
# 1  2025-01-05 2025-01-05 00:00:00+00:00                       NaT
# 2  2025-01-05 2025-01-05 05:23:00+00:00 2025-01-05 06:00:00+00:00
# 3  2025-01-05 2025-01-05 05:23:00+00:00 2025-01-05 06:00:00+00:00
# 4  2025-01-05 2025-01-05 05:25:00+00:00 2025-01-05 05:28:00+00:00
#
#           arrival_scheduled            arrival_actual
# 0 2025-01-05 07:50:00+00:00 2025-01-05 07:33:00+00:00
# 1 2025-01-05 01:04:00+00:00                       NaT
# 2 2025-01-05 06:51:00+00:00 2025-01-05 06:47:00+00:00
# 3 2025-01-05 06:51:00+00:00 2025-01-05 06:47:00+00:00
# 4 2025-01-05 06:40:00+00:00 2025-01-05 06:15:00+00:00

# %%
#calculate delay time in minutes

# Departure delay in minutes
df['dep_delay_min'] = (
    (df['departure_actual'] - df['departure_scheduled'])
    .dt.total_seconds() / 60
)

# Arrival delay in minutes
df['arr_delay_min'] = (
    (df['arrival_actual'] - df['arrival_scheduled'])
    .dt.total_seconds() / 60
)

print("the negative value means the flight either arrived/departed early.")

df[['departure_scheduled', 'departure_actual', 'dep_delay_min',
    'arrival_scheduled', 'arrival_actual', 'arr_delay_min']].head()
# Out:
# the negative value means the flight either arrived/departed early.
#         departure_scheduled          departure_actual  dep_delay_min  \
# 0 2025-01-05 05:00:00+00:00 2025-01-05 05:20:00+00:00           20.0
# 1 2025-01-05 00:00:00+00:00                       NaT            NaN
# 2 2025-01-05 05:23:00+00:00 2025-01-05 06:00:00+00:00           37.0
# 3 2025-01-05 05:23:00+00:00 2025-01-05 06:00:00+00:00           37.0
# 4 2025-01-05 05:25:00+00:00 2025-01-05 05:28:00+00:00            3.0
#
#           arrival_scheduled            arrival_actual  arr_delay_min
# 0 2025-01-05 07:50:00+00:00 2025-01-05 07:33:00+00:00          -17.0
# 1 2025-01-05 01:04:00+00:00                       NaT            NaN
# 2 2025-01-05 06:51:00+00:00 2025-01-05 06:47:00+00:00           -4.0
# 3 2025-01-05 06:51:00+00:00 2025-01-05 06:47:00+00:00           -4.0
# 4 2025-01-05 06:40:00+00:00 2025-01-05 06:15:00+00:00          -25.0

# %%
#handle missing values:

#  fill in missing gate terminal/gate information
df['departure_terminal'] = df['departure_terminal'].fillna("Unknown")
df['departure_gate'] = df['departure_gate'].fillna("Unknown")

# Drop flights missing flight_status (dropping flihts that do not have a flight states; prob will not happen, but checking in case)
df = df.dropna(subset=['flight_status'])


print("Cleaned up missing info. shows that there are 697 flights that have missing departing_delay info, 1364 have missing departure_actual info.")
df.isna().sum().head(15)
# Out:
# Cleaned up missing info. shows that there are 697 flights that have missing departing_delay info, 1364 have missing departure_actual info.
# flight_date                      0
# flight_status                    0
# live                          5509
# departure_airport                0
# departure_timezone               0
# departure_iata                   0
# departure_icao                   0
# departure_terminal               0
# departure_gate                   0
# departure_delay                697
# departure_scheduled              0
# departure_estimated              0
# departure_actual              1364
# departure_estimated_runway    1364
# departure_actual_runway       1364
# dtype: int64

# %%
#adding a flag (true/false) if a flight was cancelled so we can use it to analyze cancellation rates

#marks either true or false
df['is_cancelled'] = df['flight_status'].eq('cancelled')

print("Cancellation flag created.")
df[['flight_status', 'is_cancelled']].head(100)

# %%
display(df)

# %% [markdown]
# ## Model Planning

# %%
#overview of entire data set
total_flights = len(df)
total_cancelled = df['is_cancelled'].sum()

# Delayed = actual departure or arrival time does NOT match scheduled time (and not cancelled)
total_delayed = (
    (~df['is_cancelled']) &
    (
        (df['dep_delay_min'].notna() & (df['dep_delay_min'] > 0)) |
        (df['arr_delay_min'].notna() & (df['arr_delay_min'] > 0))
    )
).sum()

num_airlines = df['airline_name'].nunique()

print("---- BUF Airport Flight Summary ----")
print(f"Total flights: {total_flights}")
print(f"Total cancelled flights: {total_cancelled} ({(total_cancelled/total_flights)*100:.2f}%)")
print(f"Total delayed flights (non-cancelled, actual ≠ scheduled): {total_delayed} ({(total_delayed/total_flights)*100:.2f}%)")
print(f"Number of airlines: {num_airlines}")

df[['airline_name', 'flight_status', 'dep_delay_min', 'arr_delay_min']].head()

# %%
# Overview of cancellation info

total_flights = len(df)
total_cancelled = df['is_cancelled'].sum()
cancel_rate = (total_cancelled / total_flights) * 100
num_airlines = df['airline_name'].nunique()

print("---- BUF Airport Cancellation Summary ----")
print(f"Total flights: {total_flights}")
print(f"Total cancelled flights: {total_cancelled} ({cancel_rate:.2f}%)")
print(f"Number of airlines: {num_airlines}")

# Quick peek at flight status
display(df[['airline_name', 'flight_status']].head())

# ------- Cancellations by airline ----------

cancel_by_airline = (
    df.groupby('airline_name')['is_cancelled']
    .mean()
    .sort_values(ascending=False) * 100
)

print("\n---- Cancellation Rate by Airline (% cancelled) ----")
display(cancel_by_airline)

# number of cancelled flights by airline
cancel_counts = df.groupby('airline_name')['is_cancelled'].sum().sort_values(ascending=False)
print("\n---- Number of Cancelled Flights by Airline ----")
display(cancel_counts)

# -------- Cancellations by date (can be related to weather) ----------

cancel_by_date = df.groupby('flight_date')['is_cancelled'].mean() * 100

print("\n---- Top 10 Dates by Cancellation Rate (% cancelled) ----")
display(cancel_by_date.sort_values(ascending=False).head(10))

# %%
# ---------------------------------------
# Delay Analysis Overview
# ---------------------------------------

# 1) Numeric delay summary (minutes) for flights that actually departed
#    (exclude cancelled + missing actual departure times)

df_departed = df[(df['is_cancelled'] == False) & (df['dep_delay_min'].notna())]

print("Flights that actually departed (with dep delay data):", len(df_departed))
display(df_departed.head())

# Extract delay columns from df_departed
dep_delays = df_departed['dep_delay_min']
arr_delays = df_departed['arr_delay_min']

print("\n---- Departure Delay (Minutes) ----")
print(f"Number of departed flights with delay data: {len(dep_delays)}")
print(f"Average departure delay: {dep_delays.mean():.2f} min")
print(f"Median departure delay: {dep_delays.median():.2f} min")
print(f"90th percentile departure delay: {dep_delays.quantile(0.90):.2f} min")

print("\n---- Arrival Delay (Minutes) ----")
print(f"Number of flights with arrival delay data: {len(arr_delays)}")
print(f"Average arrival delay: {arr_delays.mean():.2f} min")
print(f"Median arrival delay: {arr_delays.median():.2f} min")
print(f"90th percentile arrival delay: {arr_delays.quantile(0.90):.2f} min")

# 2) Define "delayed" using your chosen rule:
#    A flight is delayed if actual departure OR arrival time != scheduled

df['is_delayed_exact'] = (
    (df['departure_actual'] != df['departure_scheduled']) |
    (df['arrival_actual'] != df['arrival_scheduled'])
)

# Percentage of delayed flights (based on exact time mismatch)
num_delayed = df['is_delayed_exact'].sum()
total_flights = len(df)
percent_delayed = (num_delayed / total_flights) * 100

print("\n---- Delay Summary (Exact Match Definition) ----")
print(f"Total flights: {total_flights}")
print(f"Delayed flights (actual ≠ scheduled): {num_delayed}")
print(f"Percentage delayed: {percent_delayed:.2f}%")

# Show first few delayed flights with their time differences
display(df[df['is_delayed_exact']][[
    'airline_name',
    'flight_iata',
    'departure_scheduled',
    'departure_actual',
    'arrival_scheduled',
    'arrival_actual'
]].head())

# 3) Delays by airline (using is_delayed_exact)

airline_delay_stats = df.groupby('airline_name').agg(
    total_flights=('airline_name', 'count'),
    delayed_flights=('is_delayed_exact', 'sum')
)

airline_delay_stats['delay_rate (%)'] = (
    airline_delay_stats['delayed_flights'] /
    airline_delay_stats['total_flights'] * 100
)

airline_delay_stats = airline_delay_stats.sort_values('delay_rate (%)', ascending=False)

print("\n---- Delay Rate by Airline (Actual ≠ Scheduled) ----")
display(airline_delay_stats)

# 4) Delays by specific days (helpful for potential weather impact)

daily_delay_stats = df.groupby('flight_date').agg(
    total_flights=('flight_date', 'count'),
    delayed_flights=('is_delayed_exact', 'sum')
)

daily_delay_stats['delay_rate (%)'] = (
    daily_delay_stats['delayed_flights'] /
    daily_delay_stats['total_flights'] * 100
)

print("\n---- Top 10 Days by Delay Rate ----")
display(daily_delay_stats.sort_values('delay_rate (%)', ascending=False).head(10))

# %%
#time of day (monring/midday/night) delay

# Extract hour from actual departure time
df['departure_hour'] = df['departure_actual'].dt.hour

def get_time_of_day(hour):
    if pd.isna(hour):
        return "Unknown"
    elif 0 <= hour < 6:
        return "Night (0–5)"
    elif 6 <= hour < 12:
        return "Morning (6–11)"
    elif 12 <= hour < 18:
        return "Afternoon (12–17)"
    else:
        return "Evening (18–23)"

df['time_of_day'] = df['departure_hour'].apply(get_time_of_day)

time_of_day_stats = df.groupby('time_of_day').agg(
    total_flights=('time_of_day', 'count'),
    delayed_flights=('is_delayed_exact', 'sum')
)

time_of_day_stats['delay_rate (%)'] = (
    time_of_day_stats['delayed_flights'] /
    time_of_day_stats['total_flights'] * 100
)

display(time_of_day_stats.sort_values('delay_rate (%)', ascending=False))

# %%
#delays based on gate/teminal used:

#---- TERMINAL PERFORMANCE ---- (note that all files have NULL for their terminal)


# Only consider flights that actually departed (not cancelled)
df_terminal = df[(df['is_cancelled'] == False) & (df['dep_delay_min'].notna())]

terminal_stats = df_terminal.groupby('departure_terminal').agg(
    total_flights=('dep_delay_min', 'count'),
    avg_dep_delay=('dep_delay_min', 'mean'),
    med_dep_delay=('dep_delay_min', 'median'),
)

# Add cancellation rate for each terminal
terminal_cancel_rate = (
    df.groupby('departure_terminal')['is_cancelled']
    .mean() * 100
)

terminal_stats['cancel_rate (%)'] = terminal_cancel_rate

# Final sorted table (worst-performing first)
terminal_stats = terminal_stats.sort_values('avg_dep_delay', ascending=False)

print("=== Terminal Performance (Delays & Cancellations) ===")
display(terminal_stats)



# ---- GATE PERFORMANCE ----

df_gate = df[(df['is_cancelled'] == False) & (df['dep_delay_min'].notna())]

gate_stats = df_gate.groupby('departure_gate').agg(
    total_flights=('dep_delay_min', 'count'),
    avg_dep_delay=('dep_delay_min', 'mean'),
    med_dep_delay=('dep_delay_min', 'median'),
)

gate_cancel_rate = (
    df.groupby('departure_gate')['is_cancelled']
    .mean() * 100
)

gate_stats['cancel_rate (%)'] = gate_cancel_rate

# Sort by worst delay
gate_stats = gate_stats.sort_values('avg_dep_delay', ascending=False)

print("=== Gate Performance (Delays & Cancellations) ===")
display(gate_stats.head(20))  # show top 20 worst gates

# %%
#destination performcance (seeing if certain destinations had a higher delay time)

# ---- DESTINATION PERFORMANCE ----

# Only flights that have a destination airport
df_dest = df.copy()

# Group by arrival airport (destination)
dest_stats = df_dest.groupby('arrival_airport').agg(
    total_flights=('flight_status', 'count'),
    avg_dep_delay=('dep_delay_min', 'mean'),
    avg_arr_delay=('arr_delay_min', 'mean'),
    cancellations=('is_cancelled', 'sum'),
    cancel_rate=('is_cancelled', 'mean'),
)

# Convert cancel_rate to %
dest_stats['cancel_rate'] = dest_stats['cancel_rate'] * 100

# Sort by worst arrival delay
dest_stats_sorted = dest_stats.sort_values('avg_arr_delay', ascending=False)

print("=== Destination Performance (Sorted by Arrival Delay) ===")
display(dest_stats_sorted.head(15))   # Show top 15 worst destinations


worst_arrivals = dest_stats.sort_values('avg_arr_delay', ascending=False).head(10)
print("=== Top 10 Worst Destinations by Arrival Delay ===")
display(worst_arrivals)


worst_cancel_routes = dest_stats.sort_values('cancel_rate', ascending=False).head(10)
print("=== Top 10 Destinations with Highest Cancellation Rate ===")
display(worst_cancel_routes)

# %% [markdown]
# ## Model building / Analysis

# %%
#cancellations by date in Jan:



plt.figure(figsize=(12,6))
cancel_by_date.plot(marker='o')
plt.title('Daily Cancellation Rate – January 2025')
plt.xlabel('Date')
plt.ylabel('Cancellation Rate (%)')
plt.grid(True)
plt.show()

# %%
#line chart displaying time of day delays:

# %%
#chart for gate delay:


top_gates = gate_stats.head(15)

plt.figure(figsize=(12,6))
plt.bar(top_gates.index, top_gates['avg_dep_delay'])
plt.title("Top 15 Gates by Average Departure Delay")
plt.xlabel("Gate")
plt.ylabel("Avg Delay (min)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
#array delay by destination

top15_dest = worst_arrivals.head(15)

plt.figure(figsize=(12,6))
plt.bar(top15_dest.index, top15_dest['avg_arr_delay'], color='orange')
plt.title("Top 15 Destinations by Average Arrival Delay")
plt.xlabel("Destination Airport")
plt.ylabel("Avg Arrival Delay (min)")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()



#cancellation rate by destination:

top15_cancel = worst_cancel_routes.head(15)

plt.figure(figsize=(12,6))
plt.bar(top15_cancel.index, top15_cancel['cancel_rate'], color='red')
plt.title("Top 15 Destinations by Cancellation Rate (%)")
plt.xlabel("Destination Airport")
plt.ylabel("Cancellation Rate (%)")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Discussion and Results

# %% [markdown]
# In regards to cancelled flights, we found that there were not as many cancelled flights as expected. The days with the most cancelled flights line up with inclement weather in Buffalo: January 6, 2025 had a snowstorm, and January 22, 2025 had a large freeze (Reference 2). Thus we conclude that cancellations are most significantly weather related.
#
# Note: From class: What did we find in the data
# You could also put where you're stuck and want to do more analysis.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References

# %% [markdown]
# 1. https://www.geeksforgeeks.org/python/line-chart-in-matplotlib-python/
#
# 2. https://weatherspark.com/h/m/20372/2025/1/Historical-Weather-in-January-2025-in-Buffalo-New-York-United-States

# %% [markdown]
# ## Appendix
