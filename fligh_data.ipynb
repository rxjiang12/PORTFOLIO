# %% [markdown]
# <a href="https://colab.research.google.com/github/Iamkoss/cis9650_flight_data/blob/main/fligh_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis of Flight Data from the Buffalo, NY Airport

# %% [markdown]
# ### Author: Anna Bold, Kossi Gamli, Ran Xin Jiang, Christina Pratas
# ### Date : December 8th, 2025

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 1. Introduction
# 2. Problem Statement / Research Question
# 3. Data Description
# 4. Setup and Environment
# 5. Data Loading
# 6. Data Preparation
# 7. Model Planning
# 8. Model Building / Analysis
# 9. Discussion & Interpretation
# 10. Conclusion
# 11. References
# 12. Appendix

# %% [markdown]
# ## Introduction
# This projects examines flight records from Buffalo Niagara International Airport (BUF) for the entirety of January 2025. The following 30 JSON files contain detailed information regarding flight schedules, delays, airports, and timezones, etc. The dataset shows how flights operated throughout the month, including patterns in delays, cancellations, airline performance, and schedule consistency. By organizing this raw data into a structured format, it highlights these trends and provides a clearer picture of BUF's activity during this period.

# %% [markdown]
# ## Problem Statement / Research Question

# %% [markdown]
# ## Data Description

# %% [markdown]
# ## Setup and Environment

# %%
# !pip install google-cloud-storage
# Out:
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (3.6.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.43.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.32.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.11.12)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import json
import os
import glob
from google.cloud import storage
from io import BytesIO

# %% [markdown]
# ## Data Loading

# %%
files = glob.glob("/content/cis9650_flight_data/*.json")

dfs = []  # store each file's dataframe

for file in files:
    print("Loading:", file)
    df = pd.read_csv(file)
    dfs.append(df)
    all_df = pd.concat(dfs, ignore_index=True)

print(dfs)
# Out:
# Loading: /content/cis9650_flight_data/BUF_28.json
# Loading: /content/cis9650_flight_data/BUF_19.json
# Loading: /content/cis9650_flight_data/BUF_11.json
# Loading: /content/cis9650_flight_data/BUF_20.json
# Loading: /content/cis9650_flight_data/BUF_8.json
# Loading: /content/cis9650_flight_data/BUF_23.json
# Loading: /content/cis9650_flight_data/BUF_10.json
# Loading: /content/cis9650_flight_data/BUF_26.json
# Loading: /content/cis9650_flight_data/BUF_9.json
# Loading: /content/cis9650_flight_data/BUF_2.json
# Loading: /content/cis9650_flight_data/BUF_14.json
# Loading: /content/cis9650_flight_data/BUF_29.json
# Loading: /content/cis9650_flight_data/BUF_16.json
# Loading: /content/cis9650_flight_data/BUF_1.json
# Loading: /content/cis9650_flight_data/BUF_6.json
# Loading: /content/cis9650_flight_data/BUF_4.json
# Loading: /content/cis9650_flight_data/BUF_18.json
# Loading: /content/cis9650_flight_data/BUF_12.json
# Loading: /content/cis9650_flight_data/BUF_13.json
# Loading: /content/cis9650_flight_data/BUF_24.json
# Loading: /content/cis9650_flight_data/BUF_30.json
# Loading: /content/cis9650_flight_data/BUF_21.json
# Loading: /content/cis9650_flight_data/BUF_17.json
# Loading: /content/cis9650_flight_data/BUF_25.json
# Loading: /content/cis9650_flight_data/BUF_3.json
# Loading: /content/cis9650_flight_data/BUF_5.json
# Loading: /content/cis9650_flight_data/BUF_27.json
# Loading: /content/cis9650_flight_data/BUF_22.json
# Loading: /content/cis9650_flight_data/BUF_7.json
# Loading: /content/cis9650_flight_data/BUF_15.json
# [Empty DataFrame
# Columns: [[{"flight_date": "2025-01-15",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": null,  "delay": 10,  "scheduled": "2025-01-15T00:45:00+00:00",  "estimated": "2025-01-15T00:45:00+00:00",  "actual": "2025-01-15T00:54:00+00:00",  "estimated_runway": "2025-01-15T00:54:00+00:00",  "actual_runway": "2025-01-15T00:54:00+00:00"},  "arrival": {"airport": "Love Field",  "timezone": "America/Chicago",  "iata": "DAL",  "icao": "KDAL",  "terminal": null.1,  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-15T02:55:00+00:00",  "delay": null,  "estimated": null,  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "airline": {"name": "Air Canada",  "iata": "AC",  "icao": "ACA"},  "flight": {"number": "7020",  "iata": "AC7020",  "icao": "ACA7020",  "codeshared": null},  "aircraft": {"registration": "C-FKPT",  "iata": "A320",  "icao": "A320",  "icao24": "C01C02"},  "live": null},  {"flight_date": "2025-01-15",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".1,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.2,  "gate": "8",  "delay": 130,  "scheduled": "2025-01-15T09:00:00+00:00",  "estimated": "2025-01-15T09:00:00+00:00",  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "arrival": {"airport": "Newark Liberty International",  "timezone": "America/New_York".2,  "iata": "EWR",  "icao": "KEWR",  "terminal": "A",  "gate": "34",  "baggage": null.1,  "scheduled": "2025-01-15T10:03:00+00:00",  "delay": null.1,  "estimated": null.1,  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "airline": {"name": "JetBlue Airways",  "iata": "B6",  "icao": "JBU"},  "flight": {"number": "8391",  "iata": "B68391",  "icao": "JBU8391",  "codeshared": null}.1,  "aircraft": null,  "live": null}.1,  {"flight_date": "2025-01-15".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".3,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.3,  "gate": null.2,  "delay": null.2,  "scheduled": "2025-01-15T09:54:00+00:00",  "estimated": "2025-01-15T09:54:00+00:00",  "actual": "2025-01-15T09:46:00+00:00",  "estimated_runway": "2025-01-15T09:46:00+00:00",  "actual_runway": "2025-01-15T09:46:00+00:00"},  "arrival": {"airport": "John F Kennedy International",  "timezone": "America/New_York".4,  "iata": "JFK",  "icao": "KJFK",  "terminal": null.4,  "gate": null.3,  "baggage": null.2,  "scheduled": "2025-01-15T11:24:00+00:00",  "delay": 28948958,  "estimated": null.2,  "actual": "2025-01-15T10:38:00+00:00", ...]
# Index: []
#
# [0 rows x 7097 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-30",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "12",  "delay": 4,  "scheduled": "2025-01-30T10:10:00+00:00",  "estimated": "2025-01-30T10:10:00+00:00",  "actual": "2025-01-30T10:14:00+00:00",  "estimated_runway": "2025-01-30T10:14:00+00:00",  "actual_runway": "2025-01-30T10:14:00+00:00"},  "arrival": {"airport": "Washington Dulles International",  "timezone": "America/New_York".1,  "iata": "IAD",  "icao": "KIAD",  "terminal": "M",  "gate": "6",  "baggage": "1",  "scheduled": "2025-01-30T11:36:00+00:00",  "delay": null,  "estimated": "2025-01-30T10:54:00+00:00",  "actual": "2025-01-30T10:55:00+00:00",  "estimated_runway": "2025-01-30T10:55:00+00:00",  "actual_runway": "2025-01-30T10:55:00+00:00"},  "airline": {"name": "SA AVIANCA",  "iata": "AV",  "icao": "AVA"},  "flight": {"number": "2043",  "iata": "AV2043",  "icao": "AVA2043",  "codeshared": {"airline_name": "united airlines",  "airline_iata": "ua",  "airline_icao": "ual",  "flight_number": "683",  "flight_iata": "ua683",  "flight_icao": "ual683"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-30",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "12".1,  "delay": 4.1,  "scheduled": "2025-01-30T10:10:00+00:00".1,  "estimated": "2025-01-30T10:10:00+00:00".1,  "actual": "2025-01-30T10:14:00+00:00".1,  "estimated_runway": "2025-01-30T10:14:00+00:00".1,  "actual_runway": "2025-01-30T10:14:00+00:00"}.1,  "arrival": {"airport": "Washington Dulles International".1,  "timezone": "America/New_York".3,  "iata": "IAD".1,  "icao": "KIAD".1,  "terminal": "M".1,  "gate": "6".1,  "baggage": "1".1,  "scheduled": "2025-01-30T11:36:00+00:00".1,  "delay": null.1,  "estimated": "2025-01-30T10:54:00+00:00".1,  "actual": "2025-01-30T10:55:00+00:00".1,  "estimated_runway": "2025-01-30T10:55:00+00:00".1,  "actual_runway": "2025-01-30T10:55:00+00:00"}.1,  "airline": {"name": "Copa Airlines",  "iata": "CM",  "icao": "CMP"},  "flight": {"number": "2149",  "iata": "CM2149",  "icao": "CMP2149",  "codeshared": {"airline_name": "united airlines".1,  "airline_iata": "ua".1,  "airline_icao": "ual".1,  "flight_number": "683".1,  "flight_iata": "ua683".1,  "flight_icao": "ual683"}}.1,  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-30".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "12".2,  "delay": 4.2,  "scheduled": "2025-01-30T10:10:00+00:00".2,  "estimated": "2025-01-30T10:10:00+00:00".2,  "actual": "2025-01-30T10:14:00+00:00".2,  "estimated_runway": "2025-01-30T10:14:00+00:00".2,  "actual_runway": "2025-01-30T10:14:00+00:00"}.2,  "arrival": {"airport": "Washington Dulles International".2,  "timezone": "America/New_York".5,  "iata": "IAD".2,  "icao": "KIAD".2, ...]
# Index: []
#
# [0 rows x 7378 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-29",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "22",  "delay": 45,  "scheduled": "2025-01-29T06:22:00+00:00",  "estimated": "2025-01-29T06:22:00+00:00",  "actual": "2025-01-29T07:06:00+00:00",  "estimated_runway": "2025-01-29T07:06:00+00:00",  "actual_runway": "2025-01-29T07:06:00+00:00"},  "arrival": {"airport": "Detroit Metropolitan Wayne County",  "timezone": "America/Detroit",  "iata": "DTW",  "icao": "KDTW",  "terminal": "E",  "gate": "A78",  "baggage": "4",  "scheduled": "2025-01-29T07:50:00+00:00",  "delay": null,  "estimated": null,  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "airline": {"name": "Aeromexico",  "iata": "AM",  "icao": "AMX"},  "flight": {"number": "3489",  "iata": "AM3489",  "icao": "AMX3489",  "codeshared": {"airline_name": "delta air lines",  "airline_iata": "dl",  "airline_icao": "dal",  "flight_number": "2285",  "flight_iata": "dl2285",  "flight_icao": "dal2285"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-29",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".1,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "22".1,  "delay": 45.1,  "scheduled": "2025-01-29T06:22:00+00:00".1,  "estimated": "2025-01-29T06:22:00+00:00".1,  "actual": "2025-01-29T07:06:00+00:00".1,  "estimated_runway": "2025-01-29T07:06:00+00:00".1,  "actual_runway": "2025-01-29T07:06:00+00:00"}.1,  "arrival": {"airport": "Detroit Metropolitan Wayne County".1,  "timezone": "America/Detroit".1,  "iata": "DTW".1,  "icao": "KDTW".1,  "terminal": "E".1,  "gate": "A78".1,  "baggage": "4".1,  "scheduled": "2025-01-29T07:50:00+00:00".1,  "delay": null.1,  "estimated": null.1,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "Korean Air",  "iata": "KE",  "icao": "KAL"},  "flight": {"number": "3388",  "iata": "KE3388",  "icao": "KAL3388",  "codeshared": {"airline_name": "delta air lines".1,  "airline_iata": "dl".1,  "airline_icao": "dal".1,  "flight_number": "2285".1,  "flight_iata": "dl2285".1,  "flight_icao": "dal2285"}}.1,  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-29".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".2,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "22".2,  "delay": 45.2,  "scheduled": "2025-01-29T06:22:00+00:00".2,  "estimated": "2025-01-29T06:22:00+00:00".2,  "actual": "2025-01-29T07:06:00+00:00".2,  "estimated_runway": "2025-01-29T07:06:00+00:00".2,  "actual_runway": "2025-01-29T07:06:00+00:00"}.2,  "arrival": {"airport": "Detroit Metropolitan Wayne County".2,  "timezone": "America/Detroit".2,  "iata": "DTW".2,  "icao": "KDTW".2, ...]
# Index: []
#
# [0 rows x 7063 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-31",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "8",  "delay": null,  "scheduled": "2025-01-31T06:00:00+00:00",  "estimated": "2025-01-31T06:00:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "John F Kennedy International",  "timezone": "America/New_York".1,  "iata": "JFK",  "icao": "KJFK",  "terminal": "5",  "gate": "7",  "baggage": "2",  "scheduled": "2025-01-31T07:38:00+00:00",  "delay": null.1,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "British Airways",  "iata": "BA",  "icao": "BAW"},  "flight": {"number": "8304",  "iata": "BA8304",  "icao": "BAW8304",  "codeshared": {"airline_name": "jetblue airways",  "airline_iata": "b6",  "airline_icao": "jbu",  "flight_number": "141",  "flight_iata": "b6141",  "flight_icao": "jbu141"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-31",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "8".1,  "delay": null.2,  "scheduled": "2025-01-31T06:00:00+00:00".1,  "estimated": "2025-01-31T06:00:00+00:00".1,  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "arrival": {"airport": "John F Kennedy International".1,  "timezone": "America/New_York".3,  "iata": "JFK".1,  "icao": "KJFK".1,  "terminal": "5".1,  "gate": "7".1,  "baggage": "2".1,  "scheduled": "2025-01-31T07:38:00+00:00".1,  "delay": null.3,  "estimated": null.1,  "actual": null.3,  "estimated_runway": null.3,  "actual_runway": null}.3,  "airline": {"name": "Aer Lingus",  "iata": "EI",  "icao": "EIN"},  "flight": {"number": "5027",  "iata": "EI5027",  "icao": "EIN5027",  "codeshared": {"airline_name": "jetblue airways".1,  "airline_iata": "b6".1,  "airline_icao": "jbu".1,  "flight_number": "141".1,  "flight_iata": "b6141".1,  "flight_icao": "jbu141"}}.1,  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-31".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "8".2,  "delay": null.4,  "scheduled": "2025-01-31T06:00:00+00:00".2,  "estimated": "2025-01-31T06:00:00+00:00".2,  "actual": null.4,  "estimated_runway": null.4,  "actual_runway": null}.4,  "arrival": {"airport": "John F Kennedy International".2,  "timezone": "America/New_York".5,  "iata": "JFK".2,  "icao": "KJFK".2, ...]
# Index: []
#
# [0 rows x 7651 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-17",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "18",  "delay": 14,  "scheduled": "2025-01-17T13:05:00+00:00",  "estimated": "2025-01-17T13:05:00+00:00",  "actual": "2025-01-17T13:18:00+00:00",  "estimated_runway": "2025-01-17T13:18:00+00:00",  "actual_runway": "2025-01-17T13:18:00+00:00"},  "arrival": {"airport": "Sky Harbor International",  "timezone": "America/Phoenix",  "iata": "PHX",  "icao": "KPHX",  "terminal": "4",  "gate": "D2",  "baggage": "6",  "scheduled": "2025-01-17T16:10:00+00:00",  "delay": null,  "estimated": "2025-01-17T15:35:00+00:00",  "actual": "2025-01-17T15:36:00+00:00",  "estimated_runway": "2025-01-17T15:36:00+00:00",  "actual_runway": "2025-01-17T15:36:00+00:00"},  "airline": {"name": "Southwest Airlines",  "iata": "WN",  "icao": "SWA"},  "flight": {"number": "574",  "iata": "WN574",  "icao": "SWA574",  "codeshared": null},  "aircraft": {"registration": "N929WN",  "iata": "B737",  "icao": "B737",  "icao24": "ACE19A"},  "live": null},  {"flight_date": "2025-01-17",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".1,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "16",  "delay": 9,  "scheduled": "2025-01-17T11:00:00+00:00",  "estimated": "2025-01-17T11:00:00+00:00",  "actual": "2025-01-17T11:08:00+00:00",  "estimated_runway": "2025-01-17T11:08:00+00:00",  "actual_runway": "2025-01-17T11:08:00+00:00"},  "arrival": {"airport": "Baltimore/Washington International Thurgood Marshall",  "timezone": "America/New_York".2,  "iata": "BWI",  "icao": "KBWI",  "terminal": null.2,  "gate": "B3",  "baggage": "6".1,  "scheduled": "2025-01-17T12:15:00+00:00",  "delay": null.1,  "estimated": "2025-01-17T11:58:00+00:00",  "actual": "2025-01-17T11:58:00+00:00",  "estimated_runway": "2025-01-17T11:58:00+00:00",  "actual_runway": "2025-01-17T11:58:00+00:00"},  "airline": {"name": "Southwest Airlines".1,  "iata": "WN".1,  "icao": "SWA"}.1,  "flight": {"number": "1682",  "iata": "WN1682",  "icao": "SWA1682",  "codeshared": null}.1,  "aircraft": {"registration": "N961WN",  "iata": "B737".1,  "icao": "B737".1,  "icao24": "AD61DE"},  "live": null}.1,  {"flight_date": "2025-01-17".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".3,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.3,  "gate": null,  "delay": 36,  "scheduled": "2025-01-17T11:00:00+00:00".1,  "estimated": "2025-01-17T11:00:00+00:00".1,  "actual": "2025-01-17T11:36:00+00:00",  "estimated_runway": "2025-01-17T11:36:00+00:00",  "actual_runway": "2025-01-17T11:36:00+00:00"},  "arrival": {"airport": "Westchester County Apt",  "timezone": "America/New_York".4,  "iata": "HPN",  "icao": "KHPN",  "terminal": null.4,  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-17T12:37:00+00:00", ...]
# Index: []
#
# [0 rows x 6234 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-25",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "6",  "delay": 31,  "scheduled": "2025-01-25T05:21:00+00:00",  "estimated": "2025-01-25T05:21:00+00:00",  "actual": "2025-01-25T05:52:00+00:00",  "estimated_runway": "2025-01-25T05:52:00+00:00",  "actual_runway": "2025-01-25T05:52:00+00:00"},  "arrival": {"airport": "Miami International Airport",  "timezone": "America/New_York".1,  "iata": "MIA",  "icao": "KMIA",  "terminal": "N",  "gate": "D60",  "baggage": "21",  "scheduled": "2025-01-25T09:04:00+00:00",  "delay": null,  "estimated": null,  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "airline": {"name": "Qatar Airways",  "iata": "QR",  "icao": "QTR"},  "flight": {"number": "9101",  "iata": "QR9101",  "icao": "QTR9101",  "codeshared": {"airline_name": "american airlines",  "airline_iata": "aa",  "airline_icao": "aal",  "flight_number": "4753",  "flight_iata": "aa4753",  "flight_icao": "aal4753"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-25",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "6".1,  "delay": 31.1,  "scheduled": "2025-01-25T05:21:00+00:00".1,  "estimated": "2025-01-25T05:21:00+00:00".1,  "actual": "2025-01-25T05:52:00+00:00".1,  "estimated_runway": "2025-01-25T05:52:00+00:00".1,  "actual_runway": "2025-01-25T05:52:00+00:00"}.1,  "arrival": {"airport": "Miami International Airport".1,  "timezone": "America/New_York".3,  "iata": "MIA".1,  "icao": "KMIA".1,  "terminal": "N".1,  "gate": "D60".1,  "baggage": "21".1,  "scheduled": "2025-01-25T09:04:00+00:00".1,  "delay": null.1,  "estimated": null.1,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "American Airlines",  "iata": "AA",  "icao": "AAL"},  "flight": {"number": "4753",  "iata": "AA4753",  "icao": "AAL4753",  "codeshared": null},  "aircraft": {"registration": "N136HQ",  "iata": "E75S",  "icao": "E75S",  "icao24": "A09239"},  "live": null}.1,  {"flight_date": "2025-01-25".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "18",  "delay": 18,  "scheduled": "2025-01-25T05:35:00+00:00",  "estimated": "2025-01-25T05:35:00+00:00",  "actual": "2025-01-25T05:52:00+00:00".2,  "estimated_runway": "2025-01-25T05:52:00+00:00".2,  "actual_runway": "2025-01-25T05:52:00+00:00"}.2,  "arrival": {"airport": "Baltimore/Washington International Thurgood Marshall",  "timezone": "America/New_York".5,  "iata": "BWI",  "icao": "KBWI",  "terminal": "S",  "gate": "A11", ...]
# Index: []
#
# [0 rows x 6449 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-16",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": null,  "delay": 26,  "scheduled": "2025-01-16T08:00:00+00:00",  "estimated": "2025-01-16T08:00:00+00:00",  "actual": "2025-01-16T08:26:00+00:00",  "estimated_runway": "2025-01-16T08:26:00+00:00",  "actual_runway": "2025-01-16T08:26:00+00:00"},  "arrival": {"airport": "Bozeman Yellowstone International Airport",  "timezone": "America/Denver",  "iata": "BZN",  "icao": "KBZN",  "terminal": null.1,  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-16T10:13:00+00:00",  "delay": 2,  "estimated": "2025-01-16T10:16:00+00:00",  "actual": "2025-01-16T10:15:00+00:00",  "estimated_runway": "2025-01-16T10:15:00+00:00",  "actual_runway": "2025-01-16T10:15:00+00:00"},  "airline": {"name": "Private owner",  "iata": null,  "icao": null},  "flight": {"number": "751",  "iata": null.1,  "icao": null,  "codeshared": null},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-16",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".1,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.2,  "gate": null.2,  "delay": 10,  "scheduled": "2025-01-16T03:54:00+00:00",  "estimated": "2025-01-16T03:54:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Teterboro",  "timezone": "America/New_York".2,  "iata": "TEB",  "icao": "KTEB",  "terminal": null.3,  "gate": null.3,  "baggage": null.1,  "scheduled": "2025-01-16T04:57:00+00:00",  "delay": null,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "NetJets Aviation",  "iata": "1I",  "icao": "EJA"},  "flight": {"number": "906",  "iata": "1I906",  "icao": "EJA906",  "codeshared": null}.1,  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-16".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".3,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.4,  "gate": "4",  "delay": null.1,  "scheduled": "2025-01-16T05:21:00+00:00",  "estimated": "2025-01-16T05:21:00+00:00",  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "arrival": {"airport": "Ronald Reagan Washington National Airport",  "timezone": "America/New_York".4,  "iata": "DCA",  "icao": "KDCA",  "terminal": "2",  "gate": "E48",  "baggage": "7",  "scheduled": "2025-01-16T06:52:00+00:00",  "delay": null.2,  "estimated": null.1,  "actual": null.3,  "estimated_runway": null.3,  "actual_runway": null}.3,  "airline": {"name": "AlphaSky", ...]
# Index: []
#
# [0 rows x 7558 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-13",  "flight_status": "cancelled",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": null,  "delay": null,  "scheduled": "2025-01-13T16:10:00+00:00",  "estimated": "2025-01-13T16:10:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Washington Dulles International",  "timezone": "America/New_York".1,  "iata": "IAD",  "icao": "KIAD",  "terminal": "M",  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-13T17:27:00+00:00",  "delay": null.1,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "United Airlines",  "iata": "UA",  "icao": "UAL"},  "flight": {"number": "3905",  "iata": "UA3905",  "icao": "UAL3905",  "codeshared": null},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-13",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "4",  "delay": 34,  "scheduled": "2025-01-13T05:21:00+00:00",  "estimated": "2025-01-13T05:21:00+00:00",  "actual": "2025-01-13T05:54:00+00:00",  "estimated_runway": "2025-01-13T05:54:00+00:00",  "actual_runway": "2025-01-13T05:54:00+00:00"},  "arrival": {"airport": "Ronald Reagan Washington National Airport",  "timezone": "America/New_York".3,  "iata": "DCA",  "icao": "KDCA",  "terminal": "2",  "gate": "E55",  "baggage": "10",  "scheduled": "2025-01-13T06:52:00+00:00",  "delay": null.2,  "estimated": "2025-01-13T06:43:00+00:00",  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "airline": {"name": "AlphaSky",  "iata": "AS",  "icao": "JAG"},  "flight": {"number": "6276",  "iata": "AS6276",  "icao": "JAG6276",  "codeshared": {"airline_name": "american airlines",  "airline_iata": "aa",  "airline_icao": "aal",  "flight_number": "5312",  "flight_iata": "aa5312",  "flight_icao": "aal5312"}},  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-13".1,  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "4".1,  "delay": 34.1,  "scheduled": "2025-01-13T05:21:00+00:00".1,  "estimated": "2025-01-13T05:21:00+00:00".1,  "actual": "2025-01-13T05:54:00+00:00".1,  "estimated_runway": "2025-01-13T05:54:00+00:00".1,  "actual_runway": "2025-01-13T05:54:00+00:00"}.1,  "arrival": {"airport": "Ronald Reagan Washington National Airport".1,  "timezone": "America/New_York".5,  "iata": "DCA".1,  "icao": "KDCA".1,  "terminal": "2".1,  "gate": "E55".1,  "baggage": "10".1,  "scheduled": "2025-01-13T06:52:00+00:00".1,  "delay": null.3, ...]
# Index: []
#
# [0 rows x 7597 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-28",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "4",  "delay": 22,  "scheduled": "2025-01-28T05:21:00+00:00",  "estimated": "2025-01-28T05:21:00+00:00",  "actual": "2025-01-28T05:42:00+00:00",  "estimated_runway": "2025-01-28T05:42:00+00:00",  "actual_runway": "2025-01-28T05:42:00+00:00"},  "arrival": {"airport": "Ronald Reagan Washington National Airport",  "timezone": "America/New_York".1,  "iata": "DCA",  "icao": "KDCA",  "terminal": "2",  "gate": "E55",  "baggage": "10",  "scheduled": "2025-01-28T06:52:00+00:00",  "delay": null,  "estimated": null,  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "airline": {"name": "AlphaSky",  "iata": "AS",  "icao": "JAG"},  "flight": {"number": "6276",  "iata": "AS6276",  "icao": "JAG6276",  "codeshared": {"airline_name": "american airlines",  "airline_iata": "aa",  "airline_icao": "aal",  "flight_number": "5312",  "flight_iata": "aa5312",  "flight_icao": "aal5312"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-28",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "4".1,  "delay": 22.1,  "scheduled": "2025-01-28T05:21:00+00:00".1,  "estimated": "2025-01-28T05:21:00+00:00".1,  "actual": "2025-01-28T05:42:00+00:00".1,  "estimated_runway": "2025-01-28T05:42:00+00:00".1,  "actual_runway": "2025-01-28T05:42:00+00:00"}.1,  "arrival": {"airport": "Ronald Reagan Washington National Airport".1,  "timezone": "America/New_York".3,  "iata": "DCA".1,  "icao": "KDCA".1,  "terminal": "2".1,  "gate": "E55".1,  "baggage": "10".1,  "scheduled": "2025-01-28T06:52:00+00:00".1,  "delay": null.1,  "estimated": null.1,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "American Airlines",  "iata": "AA",  "icao": "AAL"},  "flight": {"number": "5312",  "iata": "AA5312",  "icao": "AAL5312",  "codeshared": null},  "aircraft": {"registration": "N516AE",  "iata": "CRJ7",  "icao": "CRJ7",  "icao24": "A677BE"},  "live": null}.1,  {"flight_date": "2025-01-28".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "5",  "delay": 37,  "scheduled": "2025-01-28T06:00:00+00:00",  "estimated": "2025-01-28T06:00:00+00:00",  "actual": "2025-01-28T06:37:00+00:00",  "estimated_runway": "2025-01-28T06:37:00+00:00",  "actual_runway": "2025-01-28T06:37:00+00:00"},  "arrival": {"airport": "Charlotte Douglas",  "timezone": "America/New_York".5,  "iata": "CLT",  "icao": "KCLT",  "terminal": "B",  "gate": "B5", ...]
# Index: []
#
# [0 rows x 6903 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-04",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": null,  "delay": 182,  "scheduled": "2025-01-04T10:20:00+00:00",  "estimated": "2025-01-04T10:20:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Syracuse Hancock International Airport",  "timezone": "America/New_York".1,  "iata": "SYR",  "icao": "KSYR",  "terminal": "B",  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-04T13:45:00+00:00",  "delay": null,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "SkyWest Airlines",  "iata": "OO",  "icao": "SKW"},  "flight": {"number": "3652",  "iata": "OO3652",  "icao": "SKW3652",  "codeshared": null},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-04",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "15",  "delay": 40,  "scheduled": "2025-01-04T05:00:00+00:00",  "estimated": "2025-01-04T05:00:00+00:00",  "actual": "2025-01-04T05:39:00+00:00",  "estimated_runway": "2025-01-04T05:39:00+00:00",  "actual_runway": "2025-01-04T05:39:00+00:00"},  "arrival": {"airport": "Sky Harbor International",  "timezone": "America/Phoenix",  "iata": "PHX",  "icao": "KPHX",  "terminal": "4",  "gate": "C14",  "baggage": "2",  "scheduled": "2025-01-04T07:55:00+00:00",  "delay": 27,  "estimated": "2025-01-04T08:21:00+00:00",  "actual": "2025-01-04T08:22:00+00:00",  "estimated_runway": "2025-01-04T08:22:00+00:00",  "actual_runway": "2025-01-04T08:22:00+00:00"},  "airline": {"name": "Southwest Airlines",  "iata": "WN",  "icao": "SWA"},  "flight": {"number": "4517",  "iata": "WN4517",  "icao": "SWA4517",  "codeshared": null}.1,  "aircraft": {"registration": "N8631A",  "iata": "B738",  "icao": "B738",  "icao24": "ABDC78"},  "live": null}.1,  {"flight_date": "2025-01-04".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".3,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "4",  "delay": 6,  "scheduled": "2025-01-04T05:20:00+00:00",  "estimated": "2025-01-04T05:20:00+00:00",  "actual": "2025-01-04T05:26:00+00:00",  "estimated_runway": "2025-01-04T05:26:00+00:00",  "actual_runway": "2025-01-04T05:26:00+00:00"},  "arrival": {"airport": "Miami International Airport",  "timezone": "America/New_York".4,  "iata": "MIA",  "icao": "KMIA",  "terminal": "N",  "gate": "D60",  "baggage": "21",  "scheduled": "2025-01-04T08:44:00+00:00",  "delay": null.1,  "estimated": "2025-01-04T07:58:00+00:00",  "actual": "2025-01-04T07:57:00+00:00", ...]
# Index: []
#
# [0 rows x 7711 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-18",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": null,  "delay": 13,  "scheduled": "2025-01-18T07:24:00+00:00",  "estimated": "2025-01-18T07:24:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Philadelphia International",  "timezone": "America/New_York".1,  "iata": "PHL",  "icao": "KPHL",  "terminal": "A",  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-18T08:26:00+00:00",  "delay": null,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "UPS Airlines",  "iata": "5X",  "icao": "UPS"},  "flight": {"number": "7847",  "iata": "5X7847",  "icao": "UPS7847",  "codeshared": null},  "aircraft": {"registration": "N141UP",  "iata": "A306",  "icao": "A306",  "icao24": "A0A837"},  "live": null},  {"flight_date": "2025-01-18",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "18",  "delay": 24,  "scheduled": "2025-01-18T07:30:00+00:00",  "estimated": "2025-01-18T07:30:00+00:00",  "actual": "2025-01-18T07:54:00+00:00",  "estimated_runway": "2025-01-18T07:54:00+00:00",  "actual_runway": "2025-01-18T07:54:00+00:00"},  "arrival": {"airport": "Sky Harbor International",  "timezone": "America/Phoenix",  "iata": "PHX",  "icao": "KPHX",  "terminal": "4",  "gate": "D7",  "baggage": "6",  "scheduled": "2025-01-18T10:35:00+00:00",  "delay": null.1,  "estimated": "2025-01-18T10:30:00+00:00",  "actual": "2025-01-18T10:31:00+00:00",  "estimated_runway": "2025-01-18T10:31:00+00:00",  "actual_runway": "2025-01-18T10:31:00+00:00"},  "airline": {"name": "Southwest Airlines",  "iata": "WN",  "icao": "SWA"},  "flight": {"number": "3043",  "iata": "WN3043",  "icao": "SWA3043",  "codeshared": null}.1,  "aircraft": {"registration": "N8639B",  "iata": "B738",  "icao": "B738",  "icao24": "ABDD91"},  "live": null}.1,  {"flight_date": "2025-01-18".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".3,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "7",  "delay": 5,  "scheduled": "2025-01-18T08:55:00+00:00",  "estimated": "2025-01-18T08:55:00+00:00",  "actual": "2025-01-18T09:00:00+00:00",  "estimated_runway": "2025-01-18T09:00:00+00:00",  "actual_runway": "2025-01-18T09:00:00+00:00"},  "arrival": {"airport": "Logan International",  "timezone": "America/New_York".4,  "iata": "BOS",  "icao": "KBOS",  "terminal": "C",  "gate": "C11",  "baggage": "2",  "scheduled": "2025-01-18T10:25:00+00:00", ...]
# Index: []
#
# [0 rows x 5736 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-23",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "4",  "delay": 20,  "scheduled": "2025-01-23T05:21:00+00:00",  "estimated": "2025-01-23T05:21:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Ronald Reagan Washington National Airport",  "timezone": "America/New_York".1,  "iata": "DCA",  "icao": "KDCA",  "terminal": "2",  "gate": "E56",  "baggage": "8",  "scheduled": "2025-01-23T06:52:00+00:00",  "delay": null,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "AlphaSky",  "iata": "AS",  "icao": "JAG"},  "flight": {"number": "6276",  "iata": "AS6276",  "icao": "JAG6276",  "codeshared": {"airline_name": "american airlines",  "airline_iata": "aa",  "airline_icao": "aal",  "flight_number": "5312",  "flight_iata": "aa5312",  "flight_icao": "aal5312"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-23",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "4".1,  "delay": 20.1,  "scheduled": "2025-01-23T05:21:00+00:00".1,  "estimated": "2025-01-23T05:21:00+00:00".1,  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "arrival": {"airport": "Ronald Reagan Washington National Airport".1,  "timezone": "America/New_York".3,  "iata": "DCA".1,  "icao": "KDCA".1,  "terminal": "2".1,  "gate": "E56".1,  "baggage": "8".1,  "scheduled": "2025-01-23T06:52:00+00:00".1,  "delay": null.1,  "estimated": null.1,  "actual": null.3,  "estimated_runway": null.3,  "actual_runway": null}.3,  "airline": {"name": "American Airlines",  "iata": "AA",  "icao": "AAL"},  "flight": {"number": "5312",  "iata": "AA5312",  "icao": "AAL5312",  "codeshared": null},  "aircraft": {"registration": "N507AE",  "iata": "CRJ7",  "icao": "CRJ7",  "icao24": "A653F6"},  "live": null}.1,  {"flight_date": "2025-01-23".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "5",  "delay": 14,  "scheduled": "2025-01-23T06:00:00+00:00",  "estimated": "2025-01-23T06:00:00+00:00",  "actual": null.4,  "estimated_runway": null.4,  "actual_runway": null}.4,  "arrival": {"airport": "Charlotte Douglas",  "timezone": "America/New_York".5,  "iata": "CLT",  "icao": "KCLT",  "terminal": null.3,  "gate": "B12", ...]
# Index: []
#
# [0 rows x 7394 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-01",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "3",  "delay": 3,  "scheduled": "2025-01-01T05:45:00+00:00",  "estimated": "2025-01-01T05:45:00+00:00",  "actual": "2025-01-01T05:48:00+00:00",  "estimated_runway": "2025-01-01T05:48:00+00:00",  "actual_runway": "2025-01-01T05:48:00+00:00"},  "arrival": {"airport": "Southwest Florida International",  "timezone": "America/New_York".1,  "iata": "RSW",  "icao": "KRSW",  "terminal": "3",  "gate": "B5",  "baggage": "13",  "scheduled": "2025-01-01T09:09:00+00:00",  "delay": null,  "estimated": "2025-01-01T08:28:00+00:00",  "actual": "2025-01-01T08:29:00+00:00",  "estimated_runway": "2025-01-01T08:29:00+00:00",  "actual_runway": "2025-01-01T08:29:00+00:00"},  "airline": {"name": "Frontier Airlines",  "iata": "F9",  "icao": "FFT"},  "flight": {"number": "3955",  "iata": "F93955",  "icao": "FFT3955",  "codeshared": null},  "aircraft": {"registration": "N395FR",  "iata": "A20N",  "icao": "A20N",  "icao24": "A495E9"},  "live": null},  {"flight_date": "2025-01-01",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "5",  "delay": 13,  "scheduled": "2025-01-01T06:00:00+00:00",  "estimated": "2025-01-01T06:00:00+00:00",  "actual": "2025-01-01T06:13:00+00:00",  "estimated_runway": "2025-01-01T06:13:00+00:00",  "actual_runway": "2025-01-01T06:13:00+00:00"},  "arrival": {"airport": "Charlotte Douglas",  "timezone": "America/New_York".3,  "iata": "CLT",  "icao": "KCLT",  "terminal": "B",  "gate": "D3",  "baggage": "7",  "scheduled": "2025-01-01T08:12:00+00:00",  "delay": null.1,  "estimated": "2025-01-01T07:38:00+00:00",  "actual": "2025-01-01T07:40:00+00:00",  "estimated_runway": "2025-01-01T07:40:00+00:00",  "actual_runway": "2025-01-01T07:40:00+00:00"},  "airline": {"name": "American Airlines",  "iata": "AA",  "icao": "AAL"},  "flight": {"number": "1204",  "iata": "AA1204",  "icao": "AAL1204",  "codeshared": null}.1,  "aircraft": {"registration": "N194UW",  "iata": "A321",  "icao": "A321",  "icao24": "A178DE"},  "live": null}.1,  {"flight_date": "2025-01-01".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "12",  "delay": 17,  "scheduled": "2025-01-01T06:00:00+00:00".1,  "estimated": "2025-01-01T06:00:00+00:00".1,  "actual": "2025-01-01T06:16:00+00:00",  "estimated_runway": "2025-01-01T06:16:00+00:00",  "actual_runway": "2025-01-01T06:16:00+00:00"},  "arrival": {"airport": "Newark Liberty International",  "timezone": "America/New_York".5,  "iata": "EWR",  "icao": "KEWR",  "terminal": "C",  "gate": "136",  "baggage": "7".1,  "scheduled": "2025-01-01T07:32:00+00:00", ...]
# Index: []
#
# [0 rows x 5989 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-05",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "15",  "delay": 20,  "scheduled": "2025-01-05T05:00:00+00:00",  "estimated": "2025-01-05T05:00:00+00:00",  "actual": "2025-01-05T05:20:00+00:00",  "estimated_runway": "2025-01-05T05:20:00+00:00",  "actual_runway": "2025-01-05T05:20:00+00:00"},  "arrival": {"airport": "Orlando International",  "timezone": "America/New_York".1,  "iata": "MCO",  "icao": "KMCO",  "terminal": "A",  "gate": "129",  "baggage": "13",  "scheduled": "2025-01-05T07:50:00+00:00",  "delay": null,  "estimated": "2025-01-05T07:32:00+00:00",  "actual": "2025-01-05T07:33:00+00:00",  "estimated_runway": "2025-01-05T07:33:00+00:00",  "actual_runway": "2025-01-05T07:33:00+00:00"},  "airline": {"name": "Southwest Airlines",  "iata": "WN",  "icao": "SWA"},  "flight": {"number": "3010",  "iata": "WN3010",  "icao": "SWA3010",  "codeshared": null},  "aircraft": {"registration": "N8835Q",  "iata": "B38M",  "icao": "B38M",  "icao24": "AC2C10"},  "live": null},  {"flight_date": "2025-01-05",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": null,  "delay": 9,  "scheduled": "2025-01-05T00:00:00+00:00",  "estimated": "2025-01-05T00:00:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Philadelphia International",  "timezone": "America/New_York".3,  "iata": "PHL",  "icao": "KPHL",  "terminal": "B",  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-05T01:04:00+00:00",  "delay": null.1,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "empty",  "iata": null,  "icao": null},  "flight": {"number": null,  "iata": null.1,  "icao": null,  "codeshared": null}.1,  "aircraft": null,  "live": null}.1,  {"flight_date": "2025-01-05".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "11",  "delay": 38,  "scheduled": "2025-01-05T05:23:00+00:00",  "estimated": "2025-01-05T05:23:00+00:00",  "actual": "2025-01-05T06:00:00+00:00",  "estimated_runway": "2025-01-05T06:00:00+00:00",  "actual_runway": "2025-01-05T06:00:00+00:00"},  "arrival": {"airport": "Ronald Reagan Washington National Airport",  "timezone": "America/New_York".5,  "iata": "DCA",  "icao": "KDCA",  "terminal": "2",  "gate": "E55",  "baggage": "10",  "scheduled": "2025-01-05T06:51:00+00:00",  "delay": null.2,  "estimated": "2025-01-05T06:47:00+00:00",  "actual": "2025-01-05T06:47:00+00:00", ...]
# Index: []
#
# [0 rows x 8745 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-19",  "flight_status": "cancelled",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "10",  "delay": null,  "scheduled": "2025-01-19T10:15:00+00:00",  "estimated": "2025-01-19T10:15:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Washington Dulles International",  "timezone": "America/New_York".1,  "iata": "IAD",  "icao": "KIAD",  "terminal": "1",  "gate": "A5B",  "baggage": "3",  "scheduled": "2025-01-19T11:47:00+00:00",  "delay": null.1,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "SA AVIANCA",  "iata": "AV",  "icao": "AVA"},  "flight": {"number": "2043",  "iata": "AV2043",  "icao": "AVA2043",  "codeshared": {"airline_name": "united airlines",  "airline_iata": "ua",  "airline_icao": "ual",  "flight_number": "4875",  "flight_iata": "ua4875",  "flight_icao": "ual4875"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-19",  "flight_status": "cancelled".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "10".1,  "delay": null.2,  "scheduled": "2025-01-19T10:15:00+00:00".1,  "estimated": "2025-01-19T10:15:00+00:00".1,  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "arrival": {"airport": "Washington Dulles International".1,  "timezone": "America/New_York".3,  "iata": "IAD".1,  "icao": "KIAD".1,  "terminal": "1".1,  "gate": "A5B".1,  "baggage": "3".1,  "scheduled": "2025-01-19T11:47:00+00:00".1,  "delay": null.3,  "estimated": null.1,  "actual": null.3,  "estimated_runway": null.3,  "actual_runway": null}.3,  "airline": {"name": "Copa Airlines",  "iata": "CM",  "icao": "CMP"},  "flight": {"number": "2149",  "iata": "CM2149",  "icao": "CMP2149",  "codeshared": {"airline_name": "united airlines".1,  "airline_iata": "ua".1,  "airline_icao": "ual".1,  "flight_number": "4875".1,  "flight_iata": "ua4875".1,  "flight_icao": "ual4875"}}.1,  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-19".1,  "flight_status": "cancelled".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "12",  "delay": null.4,  "scheduled": "2025-01-19T14:43:00+00:00",  "estimated": "2025-01-19T14:43:00+00:00",  "actual": null.4,  "estimated_runway": null.4,  "actual_runway": null}.4,  "arrival": {"airport": "Washington Dulles International".2,  "timezone": "America/New_York".5,  "iata": "IAD".2,  "icao": "KIAD".2, ...]
# Index: []
#
# [0 rows x 8351 columns], Empty DataFrame
# ...
# Index: []
#
# [0 rows x 7768 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-26",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": null,  "delay": 10,  "scheduled": "2025-01-26T01:30:00+00:00",  "estimated": "2025-01-26T01:30:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Logan International",  "timezone": "America/New_York".1,  "iata": "BOS",  "icao": "KBOS",  "terminal": "A",  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-26T02:51:00+00:00",  "delay": null,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "Summit Aviation",  "iata": null,  "icao": "YEL"},  "flight": {"number": "11",  "iata": null.1,  "icao": "YEL11",  "codeshared": null},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-26",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "22",  "delay": 32,  "scheduled": "2025-01-26T06:22:00+00:00",  "estimated": "2025-01-26T06:22:00+00:00",  "actual": "2025-01-26T06:53:00+00:00",  "estimated_runway": "2025-01-26T06:53:00+00:00",  "actual_runway": "2025-01-26T06:53:00+00:00"},  "arrival": {"airport": "Detroit Metropolitan Wayne County",  "timezone": "America/Detroit",  "iata": "DTW",  "icao": "KDTW",  "terminal": "E",  "gate": "A78",  "baggage": "9",  "scheduled": "2025-01-26T07:50:00+00:00",  "delay": null.1,  "estimated": "2025-01-26T07:40:00+00:00",  "actual": "2025-01-26T07:41:00+00:00",  "estimated_runway": "2025-01-26T07:41:00+00:00",  "actual_runway": "2025-01-26T07:41:00+00:00"},  "airline": {"name": "Aeromexico",  "iata": "AM",  "icao": "AMX"},  "flight": {"number": "3489",  "iata": "AM3489",  "icao": "AMX3489",  "codeshared": {"airline_name": "delta air lines",  "airline_iata": "dl",  "airline_icao": "dal",  "flight_number": "2285",  "flight_iata": "dl2285",  "flight_icao": "dal2285"}},  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-26".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".3,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "22".1,  "delay": 32.1,  "scheduled": "2025-01-26T06:22:00+00:00".1,  "estimated": "2025-01-26T06:22:00+00:00".1,  "actual": "2025-01-26T06:53:00+00:00".1,  "estimated_runway": "2025-01-26T06:53:00+00:00".1,  "actual_runway": "2025-01-26T06:53:00+00:00"}.1,  "arrival": {"airport": "Detroit Metropolitan Wayne County".1,  "timezone": "America/Detroit".1,  "iata": "DTW".1,  "icao": "KDTW".1,  "terminal": "E".1,  "gate": "A78".1,  "baggage": "9".1,  "scheduled": "2025-01-26T07:50:00+00:00".1,  "delay": null.2, ...]
# Index: []
#
# [0 rows x 7548 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-12",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "5",  "delay": 30,  "scheduled": "2025-01-12T06:00:00+00:00",  "estimated": "2025-01-12T06:00:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Charlotte Douglas",  "timezone": "America/New_York".1,  "iata": "CLT",  "icao": "KCLT",  "terminal": "M",  "gate": "A4",  "baggage": "1",  "scheduled": "2025-01-12T08:04:00+00:00",  "delay": null,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "American Airlines",  "iata": "AA",  "icao": "AAL"},  "flight": {"number": "1204",  "iata": "AA1204",  "icao": "AAL1204",  "codeshared": null},  "aircraft": {"registration": "N551UW",  "iata": "A321",  "icao": "A321",  "icao24": "A704F9"},  "live": null},  {"flight_date": "2025-01-12",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "2A",  "delay": 27,  "scheduled": "2025-01-12T06:00:00+00:00".1,  "estimated": "2025-01-12T06:00:00+00:00".1,  "actual": "2025-01-12T06:27:00+00:00",  "estimated_runway": "2025-01-12T06:27:00+00:00",  "actual_runway": "2025-01-12T06:27:00+00:00"},  "arrival": {"airport": "Philadelphia International",  "timezone": "America/New_York".3,  "iata": "PHL",  "icao": "KPHL",  "terminal": "F",  "gate": "37",  "baggage": "F1",  "scheduled": "2025-01-12T07:24:00+00:00",  "delay": null.1,  "estimated": "2025-01-12T07:15:00+00:00",  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "airline": {"name": "American Airlines".1,  "iata": "AA".1,  "icao": "AAL"}.1,  "flight": {"number": "5769",  "iata": "AA5769",  "icao": "AAL5769",  "codeshared": null}.1,  "aircraft": {"registration": "N692AE",  "iata": "E145",  "icao": "E145",  "icao24": "A93229"},  "live": null}.1,  {"flight_date": "2025-01-12".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "7",  "delay": 2,  "scheduled": "2025-01-12T06:00:00+00:00".2,  "estimated": "2025-01-12T06:00:00+00:00".2,  "actual": "2025-01-12T06:01:00+00:00",  "estimated_runway": "2025-01-12T06:01:00+00:00",  "actual_runway": "2025-01-12T06:01:00+00:00"},  "arrival": {"airport": "John F Kennedy International",  "timezone": "America/New_York".5,  "iata": "JFK",  "icao": "KJFK",  "terminal": "5",  "gate": "8",  "baggage": "2",  "scheduled": "2025-01-12T07:38:00+00:00", ...]
# Index: []
#
# [0 rows x 8364 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-07",  "flight_status": "cancelled",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "4",  "delay": null,  "scheduled": "2025-01-07T05:21:00+00:00",  "estimated": "2025-01-07T05:21:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Ronald Reagan Washington National Airport",  "timezone": "America/New_York".1,  "iata": "DCA",  "icao": "KDCA",  "terminal": "2",  "gate": "E55",  "baggage": "10",  "scheduled": "2025-01-07T06:52:00+00:00",  "delay": null.1,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "AlphaSky",  "iata": "AS",  "icao": "JAG"},  "flight": {"number": "6276",  "iata": "AS6276",  "icao": "JAG6276",  "codeshared": {"airline_name": "american airlines",  "airline_iata": "aa",  "airline_icao": "aal",  "flight_number": "5312",  "flight_iata": "aa5312",  "flight_icao": "aal5312"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-07",  "flight_status": "cancelled".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "4".1,  "delay": null.2,  "scheduled": "2025-01-07T05:21:00+00:00".1,  "estimated": "2025-01-07T05:21:00+00:00".1,  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "arrival": {"airport": "Ronald Reagan Washington National Airport".1,  "timezone": "America/New_York".3,  "iata": "DCA".1,  "icao": "KDCA".1,  "terminal": "2".1,  "gate": "E55".1,  "baggage": "10".1,  "scheduled": "2025-01-07T06:52:00+00:00".1,  "delay": null.3,  "estimated": null.1,  "actual": null.3,  "estimated_runway": null.3,  "actual_runway": null}.3,  "airline": {"name": "American Airlines",  "iata": "AA",  "icao": "AAL"},  "flight": {"number": "5312",  "iata": "AA5312",  "icao": "AAL5312",  "codeshared": null},  "aircraft": {"registration": "N703PS",  "iata": "CRJ7",  "icao": "CRJ7",  "icao24": "A96109"},  "live": null}.1,  {"flight_date": "2025-01-07".1,  "flight_status": "cancelled".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "14",  "delay": null.4,  "scheduled": "2025-01-07T10:15:00+00:00",  "estimated": "2025-01-07T10:15:00+00:00",  "actual": null.4,  "estimated_runway": null.4,  "actual_runway": null}.4,  "arrival": {"airport": "Washington Dulles International",  "timezone": "America/New_York".5,  "iata": "IAD",  "icao": "KIAD",  "terminal": "M",  "gate": "27", ...]
# Index: []
#
# [0 rows x 7169 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-10",  "flight_status": "cancelled",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": "23",  "delay": 152,  "scheduled": "2025-01-10T18:55:00+00:00",  "estimated": "2025-01-10T18:55:00+00:00",  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Hartsfield-jackson Atlanta International",  "timezone": "America/New_York".1,  "iata": "ATL",  "icao": "KATL",  "terminal": "S",  "gate": "B10",  "baggage": "6",  "scheduled": "2025-01-10T21:21:00+00:00",  "delay": null,  "estimated": null,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "Air France",  "iata": "AF",  "icao": "AFR"},  "flight": {"number": "2877",  "iata": "AF2877",  "icao": "AFR2877",  "codeshared": {"airline_name": "delta air lines",  "airline_iata": "dl",  "airline_icao": "dal",  "flight_number": "2050",  "flight_iata": "dl2050",  "flight_icao": "dal2050"}},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-10",  "flight_status": "cancelled".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": "23".1,  "delay": 152.1,  "scheduled": "2025-01-10T18:55:00+00:00".1,  "estimated": "2025-01-10T18:55:00+00:00".1,  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "arrival": {"airport": "Hartsfield-jackson Atlanta International".1,  "timezone": "America/New_York".3,  "iata": "ATL".1,  "icao": "KATL".1,  "terminal": "S".1,  "gate": "B10".1,  "baggage": "6".1,  "scheduled": "2025-01-10T21:21:00+00:00".1,  "delay": null.1,  "estimated": null.1,  "actual": null.3,  "estimated_runway": null.3,  "actual_runway": null}.3,  "airline": {"name": "Korean Air",  "iata": "KE",  "icao": "KAL"},  "flight": {"number": "3668",  "iata": "KE3668",  "icao": "KAL3668",  "codeshared": {"airline_name": "delta air lines".1,  "airline_iata": "dl".1,  "airline_icao": "dal".1,  "flight_number": "2050".1,  "flight_iata": "dl2050".1,  "flight_icao": "dal2050"}}.1,  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-10".1,  "flight_status": "cancelled".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": "23".2,  "delay": 152.2,  "scheduled": "2025-01-10T18:55:00+00:00".2,  "estimated": "2025-01-10T18:55:00+00:00".2,  "actual": null.4,  "estimated_runway": null.4,  "actual_runway": null}.4,  "arrival": {"airport": "Hartsfield-jackson Atlanta International".2,  "timezone": "America/New_York".5,  "iata": "ATL".2,  "icao": "KATL".2, ...]
# Index: []
#
# [0 rows x 7756 columns], Empty DataFrame
# Columns: [[{"flight_date": "2025-01-20",  "flight_status": "landed",  "departure": {"airport": "Buffalo Niagara International",  "timezone": "America/New_York",  "iata": "BUF",  "icao": "KBUF",  "terminal": null,  "gate": null,  "delay": 81,  "scheduled": "2025-01-20T15:50:00+00:00",  "estimated": "2025-01-20T15:50:00+00:00",  "actual": "2025-01-20T17:10:00+00:00",  "estimated_runway": "2025-01-20T17:10:00+00:00",  "actual_runway": "2025-01-20T17:10:00+00:00"},  "arrival": {"airport": "Syracuse Hancock International Airport",  "timezone": "America/New_York".1,  "iata": "SYR",  "icao": "KSYR",  "terminal": "B",  "gate": null.1,  "baggage": null,  "scheduled": "2025-01-20T18:01:00+00:00",  "delay": null,  "estimated": null,  "actual": "2025-01-20T18:01:00+00:00",  "estimated_runway": "2025-01-20T18:01:00+00:00",  "actual_runway": "2025-01-20T18:01:00+00:00"},  "airline": {"name": "Flexjet",  "iata": "LXJ",  "icao": "LXJ"},  "flight": {"number": "415",  "iata": "LXJ415",  "icao": "LXJ415",  "codeshared": null},  "aircraft": null,  "live": null},  {"flight_date": "2025-01-20",  "flight_status": "landed".1,  "departure": {"airport": "Buffalo Niagara International".1,  "timezone": "America/New_York".2,  "iata": "BUF".1,  "icao": "KBUF".1,  "terminal": null.1,  "gate": null.2,  "delay": null.1,  "scheduled": "2025-01-20T15:50:00+00:00".1,  "estimated": "2025-01-20T15:50:00+00:00".1,  "actual": null,  "estimated_runway": null,  "actual_runway": null},  "arrival": {"airport": "Newark Liberty International",  "timezone": "America/New_York".3,  "iata": "EWR",  "icao": "KEWR",  "terminal": "C",  "gate": null.3,  "baggage": null.1,  "scheduled": "2025-01-20T18:00:00+00:00",  "delay": null.2,  "estimated": null.1,  "actual": null.1,  "estimated_runway": null.1,  "actual_runway": null}.1,  "airline": {"name": "Flexjet".1,  "iata": "LXJ".1,  "icao": "LXJ"}.1,  "flight": {"number": "415".1,  "iata": "LXJ415".1,  "icao": "LXJ415".1,  "codeshared": null}.1,  "aircraft": null.1,  "live": null}.1,  {"flight_date": "2025-01-20".1,  "flight_status": "landed".2,  "departure": {"airport": "Buffalo Niagara International".2,  "timezone": "America/New_York".4,  "iata": "BUF".2,  "icao": "KBUF".2,  "terminal": null.2,  "gate": null.4,  "delay": 6,  "scheduled": "2025-01-20T00:15:00+00:00",  "estimated": "2025-01-20T00:15:00+00:00",  "actual": null.2,  "estimated_runway": null.2,  "actual_runway": null}.2,  "arrival": {"airport": "Westchester County Apt",  "timezone": "America/New_York".5,  "iata": "HPN",  "icao": "KHPN",  "terminal": null.3,  "gate": null.5,  "baggage": null.2,  "scheduled": "2025-01-20T00:00:00+00:00",  "delay": null.3,  "estimated": null.2,  "actual": null.3,  "estimated_runway": null.3,  "actual_runway": null}.3,  "airline": {"name": "NetJets Aviation", ...]
# Index: []
#
# [0 rows x 8118 columns]]

# %% [markdown]
# ### Functions

# %%
from google.cloud import storage

def list_public_bucket(bucket_name, course, project):
    prefix = f"{course}/Project {project}/"

    client = storage.Client.create_anonymous_client()
    bucket = client.bucket(bucket_name)
    blobs = client.list_blobs(bucket, prefix=prefix)
    print(f"Listing files in public bucket '{bucket_name}' under '{prefix}':")
    filenames = []
    for blob in blobs:
        print(blob.name)
        filenames.append(blob.name)

    return filenames

# %%
from google.cloud import storage
import pandas as pd
from io import BytesIO
import os
import json

def gcs_file_to_dataframe(bucket_name: str, blob_path: str):

    # Anonymous client for public buckets
    client = storage.Client.create_anonymous_client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_path)

    # Download file content as bytes
    data = blob.download_as_bytes()

    # Detect file extension
    _, ext = os.path.splitext(blob_path.lower())

    if ext == ".csv":
        df = pd.read_csv(BytesIO(data))

    elif ext in [".xls", ".xlsx"]:
        df = pd.read_excel(BytesIO(data))

    elif ext == ".parquet":
        df = pd.read_parquet(BytesIO(data))

    elif ext == ".json":
        # Convert bytes → Python object
        text = data.decode("utf-8")
        json_obj = json.loads(text)

        # If JSON is a list → NORMAL DataFrame
        if isinstance(json_obj, list):
            df = pd.DataFrame(json_obj)

        # If JSON is a dict → flatten into rows
        elif isinstance(json_obj, dict):
            df = pd.json_normalize(json_obj)

        else:
            raise ValueError("Unsupported JSON structure")

    else:
        raise ValueError(f"Unsupported file type: {ext}")

    return df

# %%
# Example
BUCKET_NAME = "msba-online-data"
PROJECT_NUMBER = "05"
COURSE = "CIS9650"
salaries_raw = list_public_bucket(BUCKET_NAME,COURSE,PROJECT_NUMBER)
# Out:
# Listing files in public bucket 'msba-online-data' under 'CIS9650/Project 05/':
# CIS9650/Project 05/
# CIS9650/Project 05/response_0023e4c1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_018aa811-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_019321a1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_01d12a21-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_01df9b51-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_02546b41-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0341eda1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_04a44421-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_04a606f1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_04f3c6e1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_04fcb9d1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_05711491-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0661a431-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_07c39aa1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_07c66bb1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_080aa3d1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_08108981-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_08907d01-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0979e0b1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0ae2dc01-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0ae5fb31-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0b21f5f1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0b3fd071-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0ba36250-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0c8fac31-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0dfe5ec1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0e032ed1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0e3b9201-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0e5d6421-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0ec080d1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_0fab6b21-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_11207461-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_11236c81-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1155f161-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_11741a01-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_11defee1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_12ca3751-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_143380c1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_144741c1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_14818ed1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_148ea071-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_14f45531-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_15dbe421-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1747c5a1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_17615301-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_179bc721-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_17a1faf1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_180d7c11-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_18efdae1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1a638491-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1a857661-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1ab81491-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1ac4f391-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1b2a9a91-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1c02e741-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1d802de1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1da83a31-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1dd5cf51-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1dddcc51-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1e468091-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_1f1f9091-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2093d681-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_20c8db21-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_20f510b1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_20fd82e1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_21593ed1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_22333931-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_23acaf41-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_23eb50d1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_240adc31-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_241ff891-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2475c111-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2548b691-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_26c27ac1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_271b0cf1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_27387571-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_27391f71-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2793f101-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_285ab181-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_29dbc8b1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2a3d0d71-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2a4a3001-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2a57dde1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2aa92041-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2b6ecf51-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2cec8b21-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2d5c2af1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2d604671-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2d941d21-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2dc46a01-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2e8b78a1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_2ffe8611-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_306db0b1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_30924c81-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_30b35e81-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_30e1fdb1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_31a8be31-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3319f6e1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_338c2ec1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_33aa3ae1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_33ca1461-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_33fe0ac1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_34bd9f51-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3634a461-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_369db481-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_36c20231-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_36e0ca41-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3710a1f1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_37dc6b81-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_39453fc1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_39b813e1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_39e05931-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3a0ae111-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3a24bfc1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3af0fe81-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3c589a41-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3cd691f1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3d047c91-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3d293811-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3d44eb81-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3e11c681-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3f6a2001-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_3fe8b3f1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_403263f1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_404963d1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4060aa71-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4126a7a1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_427b57a1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_43044bd1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_434a2b41-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_435fcb91-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_437b7f01-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4446ac51-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_458c6831-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_46149911-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_466acc31-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4675e531-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_468dc811-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_475d3b21-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_48a93891-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_49362461-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_498dde21-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_49991e31-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_49b0b2f1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4a7c2e61-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4bc91631-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4c547b61-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4caf9081-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4cbaa981-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4cd52471-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4d983b71-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4edc49a1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4f703a51-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4fcc39d1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4fceee61-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_4ffb43a1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_50b33711-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_51f54971-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_528d31c1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_52f311c1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_52f454d1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_53146a81-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_53d00771-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_552a35b1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_55aa9e61-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5609eeb1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_560fecb1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_562db871-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_56ed25f1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_585006c0-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_58c76ec1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5928ec81-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_592d9ce1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_59555e41-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5a0ba401-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5b73dc01-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5bea59a1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5c4e64e1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5c501d21-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5c73dc51-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5d205e11-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5e8e8981-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5f07c641-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5f6f53f1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5f732f11-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_5f8ded91-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_603f7861-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_61a78951-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6225cf21-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_62923ed1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6297eeb1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_62be9411-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_635e4491-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_64c36f51-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6543ff11-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_65af40d1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_65b2dfc1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_65d85731-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_667d85f1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_67e596e1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_686207f1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_68cb74f1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_68d63fd1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_69009941-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_699c2b11-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6b0414f1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6b7ed851-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6be75af1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6bf35e51-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6c283f11-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6cbb6c71-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6e230831-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6e9d5661-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6f0a45d1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6f1585e1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6f4dc201-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_6fcf1511-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_713db5b1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_71b82af1-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_720b02b1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7234c741-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_726e3be1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_72eea491-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_745b2251-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_74c8ed61-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7528bd71-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_75687b01-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_75889b41-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_760de5f1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_777ab1d1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_77e41011-b77f-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_783ba2c1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_788e4c11-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_78ae9361-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_792c3cf1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7a98bab1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7b4e6101-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7bae02a1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7bd63931-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7c4d5311-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7db22fb1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7e7124d1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7ecb4831-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7ef29461-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_7f620d21-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_80ca6c31-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_818c4781-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_81ea8991-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_821976e1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_82801601-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_83e5b5f1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_84a87ba1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_85092eb1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_853731a1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8596f2f1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_87023831-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_87ba2871-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_881e8501-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8858e401-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_88b63451-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8a2c4f01-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8ad85861-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8b38bd51-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8b75db71-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8bd108e1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8d572921-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8df501b1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8e57b091-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8e956af1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_8ee46361-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_906b9511-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_91083521-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9176cae1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_91b19f11-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_91ff8611-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9380c451-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_941c52f1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_948ee051-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_94c4d281-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_951d8ef1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_96997601-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_973070c1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_97a37351-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_97d8c941-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9830c261-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_99b7a5f1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9a4e0471-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9ac21871-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9b04b4d1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9b4ecb41-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9cd4eb81-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9d6dbb01-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9dda2de1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9e2a5ed1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9e63d371-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_9fe81ef1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a0ef5d21-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a1597eb1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a1788d81-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a204a841-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a2fdc361-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a4168dc1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a4793541-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a49584f1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a5228a11-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a6120841-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a737caf1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a78dc841-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a7b625e1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a835bd81-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_a9247861-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_aa717221-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_aaa1e611-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_aacc6691-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ab4b61f1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ac44a421-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ad87d9e1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_adb5b5c1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_addf24d1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ae5f58b1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_af62d411-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b09d7e51-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b0c95e61-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b0f0f8b1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b17439d1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b2843851-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b3b65711-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b3ea2661-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b40cb7a1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b491a671-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b598a441-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b6dcc461-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b6fdcf01-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b7280161-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b7b70251-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b8b0e0c1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_b9f13051-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ba12d731-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ba3a9891-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bad61ca1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bbc573c1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bc686751-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bd08d091-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bd2f3261-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bd4e4131-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bdeb4be1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bee37ca1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_bf84e991-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c02fda21-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c061fbc1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c06ff391-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c0ff90c1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c2055611-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c29f7001-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c3449431-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c38052c1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c38bd991-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c425aff1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c5242241-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c5c281f1-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c6638771-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c69ea9c1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c6a80db1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c73d9e51-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c8384011-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c8e51eb1-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c982a1c1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c9b3b1f1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_c9c4b701-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ca606221-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_cb4d4841-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_cc0c2841-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_cca2f491-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ccc95661-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_cce24ab1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_cd860c21-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ce6a3fb1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_cf2af471-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_cfc56a41-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_cfe3b5c1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d0061ff1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d09d8551-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d17cafd1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d24c31a1-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d2e43671-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d2f896e0-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d3251331-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d3bb1901-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d49169e1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d574e8e1-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d5fa7721-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d60d29e1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d6412041-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d6dc0811-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d7b08431-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d89c1981-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d9121761-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d92b32c1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d97e49e1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_d9fbbea1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_dad0aff1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_dbbba901-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_dc355061-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_dc4a2601-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_dc9c52c1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_dd16e151-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_dde5b821-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_df1c6031-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_df5973c1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_df634ce1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_dfbb4601-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e02f6bf1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e0fb83a1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e23f9931-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e27de541-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e28a2f61-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e2ddbbb1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e3514561-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e4112811-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e566f0e1-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e5a00cd1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e5a4dce1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e5f3d551-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e66f4e41-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e72f09e1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e8b7fb31-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e8bc2f01-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e8c2c611-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e909a0d1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_e98a70f1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ea4e4b41-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ebd010a1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ebd8ff61-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ebf58f71-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ec2363f0-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_eca67e01-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ed73f541-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_eee714a1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_eeefb541-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ef1f0a01-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ef3ed4c1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_efc2d931-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f0953271-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f1feb4e1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f20d21e1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f250e901-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f256ea31-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f2d6f701-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f3abe851-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f5223c01-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f52c6341-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f5784e71-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f57a6391-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f5e94011-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f6cfe4a1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f83a5171-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f849f6f1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f88c6c41-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f89956d1-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f8fcc1a1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_f9ee3ba1-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fb59e0f1-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fb605eb1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fba285e1-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fbafbe91-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fc18f5c1-b77b-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fd0df231-b77d-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fe74b581-b77a-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fe7c92d1-b77c-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_feba2621-b77e-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_fec22eb1-b779-11f0-a457-2128cc60a8f4.json
# CIS9650/Project 05/response_ff361441-b77b-11f0-a457-2128cc60a8f4.json

# %%
for element in salaries_raw[1:]:
    df = gcs_file_to_dataframe(BUCKET_NAME,  element)
    print(df.head())
    break
# Out:
#    total  hidden                                               rows
# 0    250       0  [{'uuid': '406bc2ba-a769-45f9-bbbb-73af0bfef9f...

# %%
df_expanded = df.explode("details", ignore_index=True)

# 2. Convert the dict into columns
detail_cols = df_expanded["rows"].apply(pd.Series)

# 3. Merge back and drop the dict column
df_flat = pd.concat([df_expanded.drop(columns=["rows"]), detail_cols], axis=1)

df_flat
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'details'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2000411303.py in <cell line: 0>()
# ----> 1 df_expanded = df.explode("details", ignore_index=True)
#       2
#       3 # 2. Convert the dict into columns
#       4 detail_cols = df_expanded["rows"].apply(pd.Series)
#       5
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in explode(self, column, ignore_index)
#    9844         df = self.reset_index(drop=True)
#    9845         if len(columns) == 1:
# -> 9846             result = df[columns[0]].explode()
#    9847         else:
#    9848             mylen = lambda x: len(x) if (is_list_like(x) and len(x) > 0) else 1
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'details'

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ## Model Planning

# %% [markdown]
# ## Model building / Analysis

# %% [markdown]
# ## Discussion and Results

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References

# %% [markdown]
# 1. Barber, David. Bayesian Reasoning and Machine Learning. Cambridge University Press, 2012.
# 2. Aste, Tomaso, Paola Cerchiello, and Roberta Scaramozzino. "Information-Theoretic Causality Detection between Financial and Sentiment Data."Entropy, vol. 24, no. 6, 2022, pp. 1–18. DOI:10.3390/e24060774.
# 3. Metz, Cade. "Microsoft Puts OpenAI’s Sam Altman in Charge of New Advanced AI Research Team."
# The New York Times, 20 Nov. 2023, www.nytimes.com/2023/11/20/technology/openai-microsoft-altman.html

# %% [markdown]
# ## Appendix
