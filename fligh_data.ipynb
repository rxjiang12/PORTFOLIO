# %% [markdown]
# <a href="https://colab.research.google.com/github/Iamkoss/cis9650_flight_data/blob/main/fligh_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis of Flight Data from the Buffalo, NY Airport

# %% [markdown]
# ### Author: Anna Bold, Kossi Gamli, Ran Xin Jiang, Christina Pratas
# ### Date : December 8th, 2025

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 1. Introduction
# 2. Problem Statement / Research Question
# 3. Data Description
# 4. Setup and Environment
# 5. Data Loading
# 6. Data Preparation
# 7. Model Planning
# 8. Model Building / Analysis
# 9. Discussion & Interpretation
# 10. Conclusion
# 11. References
# 12. Appendix

# %% [markdown]
# ## Introduction
# This projects examines flight records from Buffalo Niagara International Airport (BUF) for the entirety of January 2025. The following 30 JSON files contain detailed information regarding flight schedules, delays, airports, and timezones, etc. The dataset shows how flights operated throughout the month, including patterns in delays, cancellations, airline performance, and schedule consistency. By organizing this raw data into a structured format, it highlights these trends and provides a clearer picture of BUF's activity during this period.

# %% [markdown]
# ## Problem Statement / Research Question

# %% [markdown]
# The research question is finding out what overlying issues the Buffalo Niagara International Airport may be having with the daily arriving and departing flights in January 2025. There are several different factors to look at, including potential problematic airlines, large discrepancies between scheduled departure/arrival times and actual departure/arrival times, and outlying flight cancellations.
#
#
# As Buffalo in January is subject to inclement weather, research will also look into if any singular days are outliers in regards to flight delays and cancellations due to weather.

# %% [markdown]
# ## Data Description

# %% [markdown]
# ## Setup and Environment

# %%
# !pip install google-cloud-storage
# Out:
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (3.6.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.43.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.32.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.11.12)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.1)

# %%
# !git clone https://github.com/Iamkoss/cis9650_flight_data.git
# Out:
# fatal: destination path 'cis9650_flight_data' already exists and is not an empty directory.

# %%
from google.cloud import storage
from io import BytesIO
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import json
import os
import glob
from google.cloud import storage
from io import BytesIO

# %% [markdown]
# ## Data Loading

# %%
# Find all BUF json files
files = sorted(glob.glob("/content/cis9650_flight_data/BUF*.json"))

# Store each file's data as a *separate* DataFrame
flight_dfs = {}  # dictionary: file_name → DataFrame

for file in files:
    print("Loading:", (file))

    with open(file, "r") as f:
        data = json.load(f)

    df = pd.json_normalize(data)

    # Save each DataFrame with name like "BUF_1"
    key = os.path.basename(file).replace(".json", "")
    flight_dfs[key] = df

print("\nLoaded files:", list(flight_dfs.keys()))
# Out:
# Loading: /content/cis9650_flight_data/BUF_1.json
# Loading: /content/cis9650_flight_data/BUF_10.json
# Loading: /content/cis9650_flight_data/BUF_11.json
# Loading: /content/cis9650_flight_data/BUF_12.json
# Loading: /content/cis9650_flight_data/BUF_13.json
# Loading: /content/cis9650_flight_data/BUF_14.json
# Loading: /content/cis9650_flight_data/BUF_15.json
# Loading: /content/cis9650_flight_data/BUF_16.json
# Loading: /content/cis9650_flight_data/BUF_17.json
# Loading: /content/cis9650_flight_data/BUF_18.json
# Loading: /content/cis9650_flight_data/BUF_19.json
# Loading: /content/cis9650_flight_data/BUF_2.json
# Loading: /content/cis9650_flight_data/BUF_20.json
# Loading: /content/cis9650_flight_data/BUF_21.json
# Loading: /content/cis9650_flight_data/BUF_22.json
# Loading: /content/cis9650_flight_data/BUF_23.json
# Loading: /content/cis9650_flight_data/BUF_24.json
# Loading: /content/cis9650_flight_data/BUF_25.json
# Loading: /content/cis9650_flight_data/BUF_26.json
# Loading: /content/cis9650_flight_data/BUF_27.json
# Loading: /content/cis9650_flight_data/BUF_28.json
# Loading: /content/cis9650_flight_data/BUF_29.json
# Loading: /content/cis9650_flight_data/BUF_3.json
# Loading: /content/cis9650_flight_data/BUF_30.json
# Loading: /content/cis9650_flight_data/BUF_4.json
# Loading: /content/cis9650_flight_data/BUF_5.json
# Loading: /content/cis9650_flight_data/BUF_6.json
# Loading: /content/cis9650_flight_data/BUF_7.json
# Loading: /content/cis9650_flight_data/BUF_8.json
# Loading: /content/cis9650_flight_data/BUF_9.json
#
# Loaded files: ['BUF_1', 'BUF_10', 'BUF_11', 'BUF_12', 'BUF_13', 'BUF_14', 'BUF_15', 'BUF_16', 'BUF_17', 'BUF_18', 'BUF_19', 'BUF_2', 'BUF_20', 'BUF_21', 'BUF_22', 'BUF_23', 'BUF_24', 'BUF_25', 'BUF_26', 'BUF_27', 'BUF_28', 'BUF_29', 'BUF_3', 'BUF_30', 'BUF_4', 'BUF_5', 'BUF_6', 'BUF_7', 'BUF_8', 'BUF_9']

# %%
# Empty list to store all flight data
all_flight_data = []

# The key is the filenames
# df is the DataFrame
for key, df in flight_dfs.items():
  records = df.to_dict(orient='records')
  all_flight_data.extend(records)

print("Total flights:", len(all_flight_data))
print("Example record:", all_flight_data[0])
# Out:
# Total flights: 5509
# Example record: {'flight_date': '2025-01-05', 'flight_status': 'landed', 'live': None, 'departure.airport': 'Buffalo Niagara International', 'departure.timezone': 'America/New_York', 'departure.iata': 'BUF', 'departure.icao': 'KBUF', 'departure.terminal': None, 'departure.gate': '15', 'departure.delay': 20.0, 'departure.scheduled': '2025-01-05T05:00:00+00:00', 'departure.estimated': '2025-01-05T05:00:00+00:00', 'departure.actual': '2025-01-05T05:20:00+00:00', 'departure.estimated_runway': '2025-01-05T05:20:00+00:00', 'departure.actual_runway': '2025-01-05T05:20:00+00:00', 'arrival.airport': 'Orlando International', 'arrival.timezone': 'America/New_York', 'arrival.iata': 'MCO', 'arrival.icao': 'KMCO', 'arrival.terminal': 'A', 'arrival.gate': '129', 'arrival.baggage': '13', 'arrival.scheduled': '2025-01-05T07:50:00+00:00', 'arrival.delay': nan, 'arrival.estimated': '2025-01-05T07:32:00+00:00', 'arrival.actual': '2025-01-05T07:33:00+00:00', 'arrival.estimated_runway': '2025-01-05T07:33:00+00:00', 'arrival.actual_runway': '2025-01-05T07:33:00+00:00', 'airline.name': 'Southwest Airlines', 'airline.iata': 'WN', 'airline.icao': 'SWA', 'flight.number': '3010', 'flight.iata': 'WN3010', 'flight.icao': 'SWA3010', 'flight.codeshared': nan, 'aircraft.registration': 'N8835Q', 'aircraft.iata': 'B38M', 'aircraft.icao': 'B38M', 'aircraft.icao24': 'AC2C10', 'aircraft': nan, 'flight.codeshared.airline_name': nan, 'flight.codeshared.airline_iata': nan, 'flight.codeshared.airline_icao': nan, 'flight.codeshared.flight_number': nan, 'flight.codeshared.flight_iata': nan, 'flight.codeshared.flight_icao': nan}

# %%
flight_record = df.to_dict(orient="records")

df_all = pd.json_normalize(flight_record)
display(df_all.head())
print(df_all.shape)
print(len(df_all))
# Out:
#   flight_date flight_status  aircraft  live              departure.airport  \
# 0  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 1  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 2  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 3  2025-01-28        landed       NaN  None  Buffalo Niagara International
# 4  2025-01-28        landed       NaN  None  Buffalo Niagara International
#
#   departure.timezone departure.iata departure.icao departure.terminal  \
# 0   America/New_York            BUF           KBUF               None
# 1   America/New_York            BUF           KBUF               None
# 2   America/New_York            BUF           KBUF               None
# 3   America/New_York            BUF           KBUF               None
# 4   America/New_York            BUF           KBUF               None
#
#   departure.gate  ...  flight.codeshared.airline_iata  \
# 0              4  ...                              aa
# 1              4  ...                             NaN
# 2              5  ...                             NaN
# 3             2A  ...                             NaN
# 4              8  ...                              b6
#
#   flight.codeshared.airline_icao flight.codeshared.flight_number  \
# 0                            aal                            5312
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            jbu                             141
#
#   flight.codeshared.flight_iata flight.codeshared.flight_icao  \
# 0                        aa5312                       aal5312
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                         b6141                        jbu141
#
#   flight.codeshared aircraft.registration aircraft.iata aircraft.icao  \
# 0               NaN                   NaN           NaN           NaN
# 1               NaN                N516AE          CRJ7          CRJ7
# 2               NaN                N129AA          A321          A321
# 3               NaN                N652RS          E145          E145
# 4               NaN                   NaN           NaN           NaN
#
#   aircraft.icao24
# 0             NaN
# 1          A677BE
# 2          A07522
# 3          A895B0
# 4             NaN
#
# [5 rows x 46 columns]
# (173, 46)
# 173

# %%
print(files)
print(len(files))
# Out:
# ['/content/cis9650_flight_data/BUF_1.json', '/content/cis9650_flight_data/BUF_10.json', '/content/cis9650_flight_data/BUF_11.json', '/content/cis9650_flight_data/BUF_12.json', '/content/cis9650_flight_data/BUF_13.json', '/content/cis9650_flight_data/BUF_14.json', '/content/cis9650_flight_data/BUF_15.json', '/content/cis9650_flight_data/BUF_16.json', '/content/cis9650_flight_data/BUF_17.json', '/content/cis9650_flight_data/BUF_18.json', '/content/cis9650_flight_data/BUF_19.json', '/content/cis9650_flight_data/BUF_2.json', '/content/cis9650_flight_data/BUF_20.json', '/content/cis9650_flight_data/BUF_21.json', '/content/cis9650_flight_data/BUF_22.json', '/content/cis9650_flight_data/BUF_23.json', '/content/cis9650_flight_data/BUF_24.json', '/content/cis9650_flight_data/BUF_25.json', '/content/cis9650_flight_data/BUF_26.json', '/content/cis9650_flight_data/BUF_27.json', '/content/cis9650_flight_data/BUF_28.json', '/content/cis9650_flight_data/BUF_29.json', '/content/cis9650_flight_data/BUF_3.json', '/content/cis9650_flight_data/BUF_30.json', '/content/cis9650_flight_data/BUF_4.json', '/content/cis9650_flight_data/BUF_5.json', '/content/cis9650_flight_data/BUF_6.json', '/content/cis9650_flight_data/BUF_7.json', '/content/cis9650_flight_data/BUF_8.json', '/content/cis9650_flight_data/BUF_9.json']
# 30

# %%
#Convert the pandas DataFrame `df_all` into a list of dictionaries where each row represents a flight record from the DataFrame
# The `orient="records"` argument ensures that each row is converted into a dictionary where column names and cell values are corresponding

flight_record = df_all.to_dict(orient="records")

# Print the first dictionary (flight record) in the `flight_record` list.
# This provides a quick way to inspect the structure and content of a single flight entry.
print(flight_record[0])

# Print the total number of flight records loaded into the `flight_record` list.
# This indicates the total count of individual flights being analyzed.
print("Total flights:", len(flight_record))
# Out:
# {'flight_date': '2025-01-28', 'flight_status': 'landed', 'aircraft': nan, 'live': None, 'departure.airport': 'Buffalo Niagara International', 'departure.timezone': 'America/New_York', 'departure.iata': 'BUF', 'departure.icao': 'KBUF', 'departure.terminal': None, 'departure.gate': '4', 'departure.delay': 22.0, 'departure.scheduled': '2025-01-28T05:21:00+00:00', 'departure.estimated': '2025-01-28T05:21:00+00:00', 'departure.actual': '2025-01-28T05:42:00+00:00', 'departure.estimated_runway': '2025-01-28T05:42:00+00:00', 'departure.actual_runway': '2025-01-28T05:42:00+00:00', 'arrival.airport': 'Ronald Reagan Washington National Airport', 'arrival.timezone': 'America/New_York', 'arrival.iata': 'DCA', 'arrival.icao': 'KDCA', 'arrival.terminal': '2', 'arrival.gate': 'E55', 'arrival.baggage': '10', 'arrival.scheduled': '2025-01-28T06:52:00+00:00', 'arrival.delay': nan, 'arrival.estimated': None, 'arrival.actual': None, 'arrival.estimated_runway': None, 'arrival.actual_runway': None, 'airline.name': 'AlphaSky', 'airline.iata': 'AS', 'airline.icao': 'JAG', 'flight.number': '6276', 'flight.iata': 'AS6276', 'flight.icao': 'JAG6276', 'flight.codeshared.airline_name': 'american airlines', 'flight.codeshared.airline_iata': 'aa', 'flight.codeshared.airline_icao': 'aal', 'flight.codeshared.flight_number': '5312', 'flight.codeshared.flight_iata': 'aa5312', 'flight.codeshared.flight_icao': 'aal5312', 'flight.codeshared': nan, 'aircraft.registration': nan, 'aircraft.iata': nan, 'aircraft.icao': nan, 'aircraft.icao24': nan}
# Total flights: 173

# %%
# Calculating the number and percentage of all cancelled flights.
def count_cancelled_flights(df):
    cancelled_flights = df[df['flight_status'] == 'cancelled']
    return len(cancelled_flights)

# Use the function on df_flights to calcuate the number as well as the percentage of all flights that were cancelled.
num_cancelled_flights = count_cancelled_flights(df_flights)
print(f"Number of cancelled flights: {num_cancelled_flights}")
percentage_cancelled_flights = (num_cancelled_flights / len(df_flights)) * 100
print(f"Percentage of cancelled flights: {percentage_cancelled_flights:.2f}%")
# Out:
# Number of cancelled flights: 53
# Percentage of cancelled flights: 0.96%

# %%
#creating a table to visualize flight information for all cancelled flights
df_flights = pd.DataFrame(all_flight_data)

cancelled_flights_df = df_flights[df_flights['flight_status'] == 'cancelled']

print(f"Total cancelled flights: {len(cancelled_flights_df)}")
display(cancelled_flights_df.head())
# Out:
# Total cancelled flights: 53
#      flight_date flight_status  live              departure.airport  \
# 585   2025-01-11     cancelled  None  Buffalo Niagara International
# 586   2025-01-11     cancelled  None  Buffalo Niagara International
# 587   2025-01-11     cancelled  None  Buffalo Niagara International
# 1409  2025-01-06     cancelled  None  Buffalo Niagara International
# 1410  2025-01-06     cancelled  None  Buffalo Niagara International
#
#      departure.timezone departure.iata departure.icao departure.terminal  \
# 585    America/New_York            BUF           KBUF               None
# 586    America/New_York            BUF           KBUF               None
# 587    America/New_York            BUF           KBUF               None
# 1409   America/New_York            BUF           KBUF               None
# 1410   America/New_York            BUF           KBUF               None
#
#      departure.gate  departure.delay  ... aircraft.iata aircraft.icao  \
# 585               5              NaN  ...          A321          A321
# 586               4              NaN  ...          CRJ7          CRJ7
# 587            None              NaN  ...           NaN           NaN
# 1409              3            153.0  ...           NaN           NaN
# 1410              3            153.0  ...          A20N          A20N
#
#      aircraft.icao24 aircraft flight.codeshared.airline_name  \
# 585           A10BBC      NaN                            NaN
# 586           A97D63      NaN                            NaN
# 587              NaN      NaN                            NaN
# 1409             NaN      NaN              frontier airlines
# 1410          A44AA2      NaN                            NaN
#
#      flight.codeshared.airline_iata flight.codeshared.airline_icao  \
# 585                             NaN                            NaN
# 586                             NaN                            NaN
# 587                             NaN                            NaN
# 1409                             f9                            fft
# 1410                            NaN                            NaN
#
#      flight.codeshared.flight_number flight.codeshared.flight_iata  \
# 585                              NaN                           NaN
# 586                              NaN                           NaN
# 587                              NaN                           NaN
# 1409                            1691                        f91691
# 1410                             NaN                           NaN
#
#      flight.codeshared.flight_icao
# 585                            NaN
# 586                            NaN
# 587                            NaN
# 1409                       fft1691
# 1410                           NaN
#
# [5 rows x 46 columns]

# %%
def count_landed_delayed_flights(df):
    landed_delayed = df[(df['flight_status'] == 'landed') & (df['departure.delay'] > 0)]
    return len(landed_delayed)

# Use the function on df_flights to calcuate the number as well as the percentage of all flights that were delayed.
num_landed_delayed_flights = count_landed_delayed_flights(df_flights)
print(f"Number of landed flights with a departure delay: {num_landed_delayed_flights}")
percentage_delayed_flights = (num_landed_delayed_flights / total_flights) * 100
print(f"Percentage of landed flights with a departure delay: {percentage_delayed_flights:.2f}%")
# Out:
# Number of landed flights with a departure delay: 4788
# Percentage of landed flights with a departure delay: 86.91%

# %%
landed_delayed_flights_df = df_flights[(df_flights['flight_status'] == 'landed') & (df_flights['departure.delay'] > 0)]
display(landed_delayed_flights_df.head())
print(f"Total cancelled flights: {len(landed_delayed_flights_df)}")
# Out:
#   flight_date flight_status  live              departure.airport  \
# 0  2025-01-05        landed  None  Buffalo Niagara International
# 1  2025-01-05        landed  None  Buffalo Niagara International
# 2  2025-01-05        landed  None  Buffalo Niagara International
# 3  2025-01-05        landed  None  Buffalo Niagara International
# 4  2025-01-05        landed  None  Buffalo Niagara International
#
#   departure.timezone departure.iata departure.icao departure.terminal  \
# 0   America/New_York            BUF           KBUF               None
# 1   America/New_York            BUF           KBUF               None
# 2   America/New_York            BUF           KBUF               None
# 3   America/New_York            BUF           KBUF               None
# 4   America/New_York            BUF           KBUF               None
#
#   departure.gate  departure.delay  ... aircraft.iata aircraft.icao  \
# 0             15             20.0  ...          B38M          B38M
# 1           None              9.0  ...           NaN           NaN
# 2             11             38.0  ...           NaN           NaN
# 3             11             38.0  ...          CRJ7          CRJ7
# 4             16              4.0  ...          B38M          B38M
#
#   aircraft.icao24 aircraft flight.codeshared.airline_name  \
# 0          AC2C10      NaN                            NaN
# 1             NaN      NaN                            NaN
# 2             NaN      NaN              american airlines
# 3          A6BF4E      NaN                            NaN
# 4          AC4CA8      NaN                            NaN
#
#   flight.codeshared.airline_iata flight.codeshared.airline_icao  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                             aa                            aal
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#   flight.codeshared.flight_number flight.codeshared.flight_iata  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                            5163                        aa5163
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#   flight.codeshared.flight_icao
# 0                           NaN
# 1                           NaN
# 2                       aal5163
# 3                           NaN
# 4                           NaN
#
# [5 rows x 46 columns]
# Total cancelled flights: 4788

# %%
#NEEDS WORKS, DONT KNOW IF WE WILL USE THIS, IT CAME FROM THE EXAMPLE
def get_file_to_dataframe(bucket_name: str, blob_path: str):



    # Download file content as bytes


    # Detect file extension


    # Convert bytes → Python object

        # If JSON is a list → NORMAL DataFrame

        # If JSON is a dict → flatten into rows
        elif isinstance(data, dict):
            df = pd.json_normalize(data)
        else:
            raise ValueError("Unsupported JSON structure")
    else:
        raise ValueError(f"Unsupported file type: {file_extension}")

    return df
# Out:
#   File "/tmp/ipython-input-4241403107.py", line 15
#     # If JSON is a dict → flatten into rows
#                                            ^
# SyntaxError: incomplete input

# %%
#NEEDS WORKS, BUT IT WILL ALLOW US TO CONVERT THE DICTIONARY INTO COLUMNS, AND THEN WE SHOULD BE ABLE TO SELECT THE COLUMNS WE WANT TO WORK ON.

df_expanded = df.explode("details", ignore_index=True)

# 2. Convert the dict into columns
detail_cols = df_expanded["rows"].apply(pd.Series)

# 3. Merge back and drop the dict column
df_flat = pd.concat([df_expanded.drop(columns=["rows"]), detail_cols], axis=1)

df_flat
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'details'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-548297852.py in <cell line: 0>()
#       1 #NEEDS WORKS, BUT IT WILL ALLOW US TO CONVERT THE DICTIONARY INTO COLUMNS, AND THEN WE SHOULD BE ABLE TO SELECT THE COLUMNS WE WANT TO WORK ON.
#       2
# ----> 3 df_expanded = df.explode("details", ignore_index=True)
#       4
#       5 # 2. Convert the dict into columns
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in explode(self, column, ignore_index)
#    9844         df = self.reset_index(drop=True)
#    9845         if len(columns) == 1:
# -> 9846             result = df[columns[0]].explode()
#    9847         else:
#    9848             mylen = lambda x: len(x) if (is_list_like(x) and len(x) > 0) else 1
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'details'

# %% [markdown]
# ## Data Preparation

# %%
display(df)
# Out:
#     flight_date flight_status  \
# 0    2025-01-28        landed
# 1    2025-01-28        landed
# 2    2025-01-28        landed
# 3    2025-01-28        landed
# 4    2025-01-28        landed
# ..          ...           ...
# 168  2025-01-28        landed
# 169  2025-01-28        landed
# 170  2025-01-28        landed
# 171  2025-01-28        landed
# 172  2025-01-28        landed
#
#                                              departure  \
# 0    {'airport': 'Buffalo Niagara International', '...
# 1    {'airport': 'Buffalo Niagara International', '...
# 2    {'airport': 'Buffalo Niagara International', '...
# 3    {'airport': 'Buffalo Niagara International', '...
# 4    {'airport': 'Buffalo Niagara International', '...
# ..                                                 ...
# 168  {'airport': 'Buffalo Niagara International', '...
# 169  {'airport': 'Buffalo Niagara International', '...
# 170  {'airport': 'Buffalo Niagara International', '...
# 171  {'airport': 'Buffalo Niagara International', '...
# 172  {'airport': 'Buffalo Niagara International', '...
#
#                                                arrival  \
# 0    {'airport': 'Ronald Reagan Washington National...
# 1    {'airport': 'Ronald Reagan Washington National...
# 2    {'airport': 'Charlotte Douglas', 'timezone': '...
# 3    {'airport': 'Philadelphia International', 'tim...
# 4    {'airport': 'John F Kennedy International', 't...
# ..                                                 ...
# 168  {'airport': 'John F Kennedy International', 't...
# 169  {'airport': 'Philadelphia International', 'tim...
# 170  {'airport': 'Fort Lauderdale Executive', 'time...
# 171  {'airport': 'Raleigh-durham International Airp...
# 172  {'airport': 'Pittsburgh International', 'timez...
#
#                                                airline  \
# 0    {'name': 'AlphaSky', 'iata': 'AS', 'icao': 'JAG'}
# 1    {'name': 'American Airlines', 'iata': 'AA', 'i...
# 2    {'name': 'American Airlines', 'iata': 'AA', 'i...
# 3    {'name': 'American Airlines', 'iata': 'AA', 'i...
# 4    {'name': 'British Airways', 'iata': 'BA', 'ica...
# ..                                                 ...
# 168  {'name': 'Qatar Airways', 'iata': 'QR', 'icao'...
# 169  {'name': 'UPS Airlines', 'iata': '5X', 'icao':...
# 170  {'name': 'Private owner', 'iata': None, 'icao'...
# 171  {'name': 'NetJets Aviation', 'iata': '1I', 'ic...
# 172  {'name': 'United Airlines', 'iata': 'UA', 'ica...
#
#                                                 flight  \
# 0    {'number': '6276', 'iata': 'AS6276', 'icao': '...
# 1    {'number': '5312', 'iata': 'AA5312', 'icao': '...
# 2    {'number': '1204', 'iata': 'AA1204', 'icao': '...
# 3    {'number': '5769', 'iata': 'AA5769', 'icao': '...
# 4    {'number': '8304', 'iata': 'BA8304', 'icao': '...
# ..                                                 ...
# 168  {'number': '3936', 'iata': 'QR3936', 'icao': '...
# 169  {'number': '1131', 'iata': '5X1131', 'icao': '...
# 170  {'number': '148', 'iata': None, 'icao': None, ...
# 171  {'number': '958', 'iata': '1I958', 'icao': 'EJ...
# 172  {'number': '3303', 'iata': 'UA3303', 'icao': '...
#
#                                               aircraft  live
# 0                                                 None   NaN
# 1    {'registration': 'N516AE', 'iata': 'CRJ7', 'ic...   NaN
# 2    {'registration': 'N129AA', 'iata': 'A321', 'ic...   NaN
# 3    {'registration': 'N652RS', 'iata': 'E145', 'ic...   NaN
# 4                                                 None   NaN
# ..                                                 ...   ...
# 168                                               None   NaN
# 169  {'registration': 'N473UP', 'iata': 'B752', 'ic...   NaN
# 170                                               None   NaN
# 171                                               None   NaN
# 172                                               None   NaN
#
# [173 rows x 8 columns]

# %%
def clean_data(df):
    # Standardize column names
    df.columns = df.columns.str.lower().str.replace(' ', '_')

    # Remove duplicate rows
    df.drop_duplicates(inplace=True)

    return df
all_dfs = clean_data(all_dfs)

# %%
display(df)
# Out:
#     flight_date flight_status  \
# 0    2025-01-28        landed
# 1    2025-01-28        landed
# 2    2025-01-28        landed
# 3    2025-01-28        landed
# 4    2025-01-28        landed
# ..          ...           ...
# 168  2025-01-28        landed
# 169  2025-01-28        landed
# 170  2025-01-28        landed
# 171  2025-01-28        landed
# 172  2025-01-28        landed
#
#                                              departure  \
# 0    {'airport': 'Buffalo Niagara International', '...
# 1    {'airport': 'Buffalo Niagara International', '...
# 2    {'airport': 'Buffalo Niagara International', '...
# 3    {'airport': 'Buffalo Niagara International', '...
# 4    {'airport': 'Buffalo Niagara International', '...
# ..                                                 ...
# 168  {'airport': 'Buffalo Niagara International', '...
# 169  {'airport': 'Buffalo Niagara International', '...
# 170  {'airport': 'Buffalo Niagara International', '...
# 171  {'airport': 'Buffalo Niagara International', '...
# 172  {'airport': 'Buffalo Niagara International', '...
#
#                                                arrival  \
# 0    {'airport': 'Ronald Reagan Washington National...
# 1    {'airport': 'Ronald Reagan Washington National...
# 2    {'airport': 'Charlotte Douglas', 'timezone': '...
# 3    {'airport': 'Philadelphia International', 'tim...
# 4    {'airport': 'John F Kennedy International', 't...
# ..                                                 ...
# 168  {'airport': 'John F Kennedy International', 't...
# 169  {'airport': 'Philadelphia International', 'tim...
# 170  {'airport': 'Fort Lauderdale Executive', 'time...
# 171  {'airport': 'Raleigh-durham International Airp...
# 172  {'airport': 'Pittsburgh International', 'timez...
#
#                                                airline  \
# 0    {'name': 'AlphaSky', 'iata': 'AS', 'icao': 'JAG'}
# 1    {'name': 'American Airlines', 'iata': 'AA', 'i...
# 2    {'name': 'American Airlines', 'iata': 'AA', 'i...
# 3    {'name': 'American Airlines', 'iata': 'AA', 'i...
# 4    {'name': 'British Airways', 'iata': 'BA', 'ica...
# ..                                                 ...
# 168  {'name': 'Qatar Airways', 'iata': 'QR', 'icao'...
# 169  {'name': 'UPS Airlines', 'iata': '5X', 'icao':...
# 170  {'name': 'Private owner', 'iata': None, 'icao'...
# 171  {'name': 'NetJets Aviation', 'iata': '1I', 'ic...
# 172  {'name': 'United Airlines', 'iata': 'UA', 'ica...
#
#                                                 flight  \
# 0    {'number': '6276', 'iata': 'AS6276', 'icao': '...
# 1    {'number': '5312', 'iata': 'AA5312', 'icao': '...
# 2    {'number': '1204', 'iata': 'AA1204', 'icao': '...
# 3    {'number': '5769', 'iata': 'AA5769', 'icao': '...
# 4    {'number': '8304', 'iata': 'BA8304', 'icao': '...
# ..                                                 ...
# 168  {'number': '3936', 'iata': 'QR3936', 'icao': '...
# 169  {'number': '1131', 'iata': '5X1131', 'icao': '...
# 170  {'number': '148', 'iata': None, 'icao': None, ...
# 171  {'number': '958', 'iata': '1I958', 'icao': 'EJ...
# 172  {'number': '3303', 'iata': 'UA3303', 'icao': '...
#
#                                               aircraft  live
# 0                                                 None   NaN
# 1    {'registration': 'N516AE', 'iata': 'CRJ7', 'ic...   NaN
# 2    {'registration': 'N129AA', 'iata': 'A321', 'ic...   NaN
# 3    {'registration': 'N652RS', 'iata': 'E145', 'ic...   NaN
# 4                                                 None   NaN
# ..                                                 ...   ...
# 168                                               None   NaN
# 169  {'registration': 'N473UP', 'iata': 'B752', 'ic...   NaN
# 170                                               None   NaN
# 171                                               None   NaN
# 172                                               None   NaN
#
# [173 rows x 8 columns]

# %% [markdown]
# ## Model Planning

# %% [markdown]
# ## Model building / Analysis

# %% [markdown]
# ## Discussion and Results

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References

# %% [markdown]
# 1. Barber, David. Bayesian Reasoning and Machine Learning. Cambridge University Press, 2012.
# 2. Aste, Tomaso, Paola Cerchiello, and Roberta Scaramozzino. "Information-Theoretic Causality Detection between Financial and Sentiment Data."Entropy, vol. 24, no. 6, 2022, pp. 1–18. DOI:10.3390/e24060774.
# 3. Metz, Cade. "Microsoft Puts OpenAI’s Sam Altman in Charge of New Advanced AI Research Team."
# The New York Times, 20 Nov. 2023, www.nytimes.com/2023/11/20/technology/openai-microsoft-altman.html

# %% [markdown]
# ## Appendix
